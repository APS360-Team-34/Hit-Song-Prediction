# %% [markdown]
# # SPOTIFY IMPORT

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\user\anaconda3\lib\site-packages (2.13.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\user\anaconda3\lib\site-packages (from spotipy) (1.15.0)
# Requirement already satisfied: requests>=2.20.0 in c:\users\user\anaconda3\lib\site-packages (from spotipy) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (3.0.4)

# %%
#Mount Google Drive
# link to your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import sys

PROJECT_ROOT = '/content/drive/My Drive/Colab Notebooks/Project/Hit-Song-Prediction/'
sys.path.append(PROJECT_ROOT)

# %%
from SpotifyConnection import get_spotify_connection
import Playlist as PL
from DataProcessing import normalize_dataframe, DataInformation, SpotifyTracksDataset

# %%
sp = get_spotify_connection()

# %% [markdown]
# # PyTorch Import

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler

# %% [markdown]
# # Other Imports

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
import random

def seed_torch(seed=0):
  random.seed(seed)

  np.random.seed(seed)
  np.random.RandomState(seed)

  torch.manual_seed(seed) 
  torch.cuda.manual_seed(seed)
  torch.cuda.manual_seed_all(seed) #seed all gpus    
  torch.backends.cudnn.deterministic = True
  torch.backends.cudnn.enabled = False  
  torch.backends.cudnn.benchmark = False

seed_torch(0)

# %% [markdown]
# # Load Data

# %%
DataInformation.list()
# Out:
# ['duration',
#  'key',
#  'mode',
#  'time_signature',
#  'acousticness',
#  'danceability',
#  'energy',
#  'instrumentalness',
#  'liveness',
#  'loudness',
#  'speechiness',
#  'valence',
#  'tempo',
#  'artist_popularity',
#  'popularity']

# %%
#pl = PL.load_playlist(PROJECT_ROOT + "playlist_2sRZldX6n9oaII70OoO3zB")
pl = PL.load_playlist("playlist_2sRZldX6n9oaII70OoO3zB")
df = pl.get_playlist_df(cols=DataInformation.list())
cols_to_normalize = DataInformation.Feature.list()
cols_to_normalize.remove('artist_popularity')
normalized_df = normalize_dataframe(df, cols_to_normalize)
# Out:
# Loaded playlist from file: playlist_2sRZldX6n9oaII70OoO3zB

# %%
normalized_df.head()
# Out:
#    duration       key  mode  time_signature  acousticness  danceability  \
# 0  0.068542  0.000000   1.0             0.8      0.111444      0.805471
# 1  0.066175  0.909091   0.0             0.8      0.344376      0.701114
# 2  0.067781  0.727273   0.0             1.0      0.241966      0.493414
# 3  0.055939  0.727273   1.0             1.0      0.127508      0.597771
# 4  0.070991  0.090909   1.0             0.8      0.035641      0.834853
#
#      energy  instrumentalness  liveness  loudness  speechiness  valence  \
# 0  0.594832               0.0  0.145511  0.858757     0.079468    0.409
# 1  0.714176               0.0  0.083591  0.896666     0.373404    0.615
# 2  0.366173               0.0  0.108359  0.787748     0.056489    0.161
# 3  0.653000               0.0  0.042931  0.865515     0.356383    0.691
# 4  0.734234               0.0  0.312693  0.874820     0.065213    0.393
#
#       tempo  artist_popularity  popularity
# 0  0.616788               98.0          76
# 1  0.627561               90.0          63
# 2  0.311547               83.0          75
# 3  0.569657               77.0          28
# 4  0.447603               84.0          75

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

x = normalized_df['acousticness']
y = normalized_df['artist_popularity']
z = normalized_df['popularity']

fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z,
           linewidths=1, alpha=.7,
           edgecolor='k',
           s = 200,
           c=z)

ax.set_xlabel('acousticness')
ax.set_ylabel('artist_popularity')
ax.set_zlabel('popularity')

plt.show()

# %% [markdown]
# # Split Data: Train, Validation, Train

# %%
def train_validate_test_split(df, train_percent=.7, validate_percent=.15, seed=50):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.iloc[perm[:train_end]]
    validate = df.iloc[perm[train_end:validate_end]]
    test = df.iloc[perm[validate_end:]]
    return train, validate, test

# %%
num_data = normalized_df.shape[0]
num_train = int(num_data*0.7)
num_val = int(num_data*0.15)
num_test = num_data - num_train - num_val

train = SpotifyTracksDataset(normalized_df.iloc[0:num_train])
val = SpotifyTracksDataset(normalized_df.iloc[num_train:num_train+num_val])
test = SpotifyTracksDataset(normalized_df.iloc[num_train+num_val:num_data])

# %%
#train, validate, test = train_validate_test_split(normalized_df)
# Out:
#       duration       key  mode  ...     tempo  artist_popularity  popularity
# 2575  0.055641  0.454545   0.0  ...  0.365645                 85          72
# 4151  0.130946  0.000000   0.0  ...  0.399769                 54          18
# 3645  0.047170  0.363636   1.0  ...  0.780879                 78          77
# 1349  0.032912  0.636364   1.0  ...  0.601433                 81          60
# 1653  0.047619  0.545455   0.0  ...  0.671723                 73          52
# ...        ...       ...   ...  ...       ...                ...         ...
# 1910  0.021356  0.909091   0.0  ...  0.731203                 73          24
# 4822  0.123240  1.000000   0.0  ...  0.541354                 39           0
# 1391  0.042004  0.636364   1.0  ...  0.371667                 92          56
# 3756  0.046058  0.818182   1.0  ...  0.470662                 88          37
# 1442  0.032721  0.818182   0.0  ...  0.525249                 85          42
#
# [3848 rows x 15 columns]

# %%
class TestNet(nn.Module):
    def __init__(self):
        super(TestNet, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(14, 50),
            nn.ReLU(),
            nn.Linear(50, 80),
            nn.ReLU(),
            nn.Linear(80, 100),
            nn.ReLU(),
            nn.Linear(100,1),
        ).to(device)
    def forward(self, x):
        x = self.layers(x)
        return x

# %%
net = TestNet()
if torch.cuda.is_available():
  net.cuda()

# %%
def predict_some(model, data, num_to_predict):
  for i in range(0, num_to_predict):
    features, target = data[i]
    features = features.to(device)
    target = target.to(device)

    out = model(features.unsqueeze(0)).clamp(min=0,max=100)
    print(f"Actual: {round(target.item(), 2)};  Predicted: {round(out.item(), 2)}")

# %%
def get_error(model, data):
  data_loader = torch.utils.data.DataLoader(data, batch_size=100)

  total_error = 0
  for features, targets in data_loader:
    features = features.to(device)
    targets = targets.to(device)

    out = model(features)
    total_error += (targets - out.clamp(min=0,max=100)).abs().sum().item()
  
  average_error = total_error/len(data)
  return average_error

# %%
def train_net(model, train, validate, num_epochs=5, learning_rate=1e-4, bs = 64):
    
    #train_ds = SpotifyTracksDataset(train)
    train_loader = torch.utils.data.DataLoader(train, batch_size=bs, shuffle=True)

    #val_ds = SpotifyTracksDataset(validate)
    val_loader = torch.utils.data.DataLoader(validate, batch_size=bs, shuffle=True)
    
    torch.manual_seed(42)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    
    iters, train_loss, val_loss, train_acc, val_acc = [], [], [], [], []

    for epoch in range(1, num_epochs + 1):
        epoch_error = 0
        epoch_loss = 0.0
        for i, batch in enumerate(train_loader, 1):
          features, targets = batch

          features = features.to(device)
          targets = targets.to(device)
          
          optimizer.zero_grad()
          out = model(features)
          
          loss = criterion(out, targets)
          loss.backward()
          optimizer.step()


          epoch_loss += loss.item()
          epoch_error += (targets - out.clamp(min=0,max=100)).abs().sum().item()

        epoch_loss = epoch_loss / i
        train_error_rate = epoch_error / len(train)
        val_error_rate = get_error(model, validate)

        train_loss.append(epoch_loss)
        train_acc.append(train_error_rate)
        val_acc.append(val_error_rate)
        iters.append(epoch)
        
        print(f"Epoch {epoch}")
        print(f"  Train Error: {train_error_rate}")
        print(f"  Valid Error: {val_error_rate}")
        print(f"  Train Loss: {epoch_loss}")

        predict_some(model, train, 5)
        predict_some(model, validate, 5)

        print("\n")

    # plotting
    plt.title("Training Curve")
    plt.plot(iters, train_loss, label="Train")
    #plt.plot(iters, val_loss, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Training Curve")
    plt.plot(iters, train_acc, label="Train")
    plt.plot(iters, val_acc, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Error")
    plt.legend(loc='best')
    plt.show()

    print("Final Training Accuracy: {}".format(100 - train_acc[-1]))
    print("Final Validation Accuracy: {}".format(100 - val_acc[-1]))

# %%
'''
def train_net(model, train, validate, num_epochs=5, learning_rate=1e-4, bs = 64):
    
    train_ds = SpotifyTracksDataset(train)
    train_loader = torch.utils.data.DataLoader(train_ds, batch_size=bs, shuffle=True)

    val_ds = SpotifyTracksDataset(validate)
    val_loader = torch.utils.data.DataLoader(val_ds, batch_size=bs, shuffle=True)
    
    torch.manual_seed(42)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    
    epochs, iters, train_loss, val_loss, train_acc, val_acc = [], [], [], [], [], []

    n = 0 # the number of iterations
    for epoch in range(num_epochs):
        error_train = 0
        error_val = 0
        for features, targets in train_loader:
            features = features.to(device)
            targets = targets.to(device)
            optimizer.zero_grad()
            out = net(features)
            loss = criterion(out, targets)
            loss.backward()
            optimizer.step()
            error_train += (targets - out.clamp(min=0,max=100)).abs().sum().item()

        #save the current training info
        iters.append(n)
        train_loss.append(loss.item())
            

        for features, targets in val_loader:
            optimizer.zero_grad()
            out = net(features)
            loss = criterion(out, targets)
            error_val += (targets - out.clamp(min=0,max=100)).abs().sum().item()

        val_loss.append(loss.item())

        #get accuracy
        train_acc.append(error_train/len(train_ds)) 
        val_acc.append(error_val/len(val_ds))
        n += 1
        print(("Epoch {}: Training Accuracy {} |"+"Validation Accuracy {}").format(epoch, train_acc[epoch], val_acc[epoch]))
        predict_some(model, train_ds, 5)
        predict_some(model, val_ds, 5)
        print("\n")

    # plotting
    plt.title("Training Curve")
    plt.plot(iters, train_loss, label="Train")
    plt.plot(iters, val_loss, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Training Curve")
    plt.plot(iters, train_acc, label="Train")
    plt.plot(iters, val_acc, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()

    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(val_acc[-1]))

'''

# %%
train_net(net, train, val, 300, 1e-3, 64)
# Out:
# Streaming output truncated to the last 5000 lines.
# Actual: 63.0;  Predicted: 49.71
# Actual: 56.0;  Predicted: 40.45
# Actual: 77.0;  Predicted: 50.72
# Actual: 86.0;  Predicted: 56.56
# Actual: 76.0;  Predicted: 43.09
#
#
# Epoch 689
#   Train Error: 20.577945899566842
#   Valid Error: 16.591016565711755
#   Train Loss: 636.4335344658523
# Actual: 76.0;  Predicted: 53.36
# Actual: 63.0;  Predicted: 53.58
# Actual: 75.0;  Predicted: 50.9
# Actual: 29.0;  Predicted: 46.55
# Actual: 75.0;  Predicted: 49.86
# Actual: 63.0;  Predicted: 51.18
# Actual: 56.0;  Predicted: 41.25
# Actual: 77.0;  Predicted: 51.75
# Actual: 86.0;  Predicted: 56.29
# Actual: 76.0;  Predicted: 42.91
#
#
# Epoch 690
#   Train Error: 20.665633752787187
#   Valid Error: 16.082130987667345
#   Train Loss: 642.1037097368084
# Actual: 76.0;  Predicted: 52.37
# Actual: 63.0;  Predicted: 52.66
# Actual: 75.0;  Predicted: 49.92
# Actual: 29.0;  Predicted: 45.77
# Actual: 75.0;  Predicted: 48.88
# Actual: 63.0;  Predicted: 50.11
# Actual: 56.0;  Predicted: 41.44
# Actual: 77.0;  Predicted: 50.71
# Actual: 86.0;  Predicted: 55.19
# Actual: 76.0;  Predicted: 42.16
#
#
# Epoch 691
#   Train Error: 20.618140099697946
#   Valid Error: 18.126811277519153
#   Train Loss: 643.1459415623399
# Actual: 76.0;  Predicted: 52.96
# Actual: 63.0;  Predicted: 53.16
# Actual: 75.0;  Predicted: 50.5
# Actual: 29.0;  Predicted: 46.21
# Actual: 75.0;  Predicted: 49.45
# Actual: 63.0;  Predicted: 50.42
# Actual: 56.0;  Predicted: 43.73
# Actual: 77.0;  Predicted: 50.94
# Actual: 86.0;  Predicted: 55.84
# Actual: 76.0;  Predicted: 42.72
#
#
# Epoch 692
#   Train Error: 20.614773304199726
#   Valid Error: 17.545321344171914
#   Train Loss: 644.6687076756211
# Actual: 76.0;  Predicted: 50.51
# Actual: 63.0;  Predicted: 50.83
# Actual: 75.0;  Predicted: 49.08
# Actual: 29.0;  Predicted: 44.17
# Actual: 75.0;  Predicted: 47.2
# Actual: 63.0;  Predicted: 49.28
# Actual: 56.0;  Predicted: 41.32
# Actual: 77.0;  Predicted: 49.81
# Actual: 86.0;  Predicted: 53.27
# Actual: 76.0;  Predicted: 40.52
#
#
# Epoch 693
#   Train Error: 20.62471463923147
#   Valid Error: 17.09498518416025
#   Train Loss: 643.1460101018187
# Actual: 76.0;  Predicted: 51.86
# Actual: 63.0;  Predicted: 52.06
# Actual: 75.0;  Predicted: 49.09
# Actual: 29.0;  Predicted: 45.26
# Actual: 75.0;  Predicted: 48.34
# Actual: 63.0;  Predicted: 49.28
# Actual: 56.0;  Predicted: 39.73
# Actual: 77.0;  Predicted: 49.49
# Actual: 86.0;  Predicted: 54.56
# Actual: 76.0;  Predicted: 41.79
#
#
# Epoch 694
#   Train Error: 20.599801347062396
#   Valid Error: 18.062378077831085
#   Train Loss: 639.787591652792
# Actual: 76.0;  Predicted: 53.08
# Actual: 63.0;  Predicted: 53.22
# Actual: 75.0;  Predicted: 48.74
# Actual: 29.0;  Predicted: 46.24
# Actual: 75.0;  Predicted: 49.47
# Actual: 63.0;  Predicted: 50.47
# Actual: 56.0;  Predicted: 39.36
# Actual: 77.0;  Predicted: 51.32
# Actual: 86.0;  Predicted: 55.9
# Actual: 76.0;  Predicted: 42.79
#
#
# Epoch 695
#   Train Error: 20.625285769202854
#   Valid Error: 17.87428320727302
#   Train Loss: 645.178925060835
# Actual: 76.0;  Predicted: 53.82
# Actual: 63.0;  Predicted: 53.72
# Actual: 75.0;  Predicted: 49.3
# Actual: 29.0;  Predicted: 46.9
# Actual: 75.0;  Predicted: 50.03
# Actual: 63.0;  Predicted: 50.62
# Actual: 56.0;  Predicted: 39.88
# Actual: 77.0;  Predicted: 51.52
# Actual: 86.0;  Predicted: 56.43
# Actual: 76.0;  Predicted: 43.45
#
#
# Epoch 696
#   Train Error: 20.728200289910646
#   Valid Error: 17.489370697910346
#   Train Loss: 643.7684066022028
# Actual: 76.0;  Predicted: 51.28
# Actual: 63.0;  Predicted: 51.55
# Actual: 75.0;  Predicted: 49.28
# Actual: 29.0;  Predicted: 44.82
# Actual: 75.0;  Predicted: 47.94
# Actual: 63.0;  Predicted: 49.53
# Actual: 56.0;  Predicted: 41.65
# Actual: 77.0;  Predicted: 50.43
# Actual: 86.0;  Predicted: 54.12
# Actual: 76.0;  Predicted: 41.22
#
#
# Epoch 697
#   Train Error: 20.61285865926445
#   Valid Error: 15.20251561137079
#   Train Loss: 642.1463467957543
# Actual: 76.0;  Predicted: 51.37
# Actual: 63.0;  Predicted: 51.56
# Actual: 75.0;  Predicted: 48.59
# Actual: 29.0;  Predicted: 44.91
# Actual: 75.0;  Predicted: 47.86
# Actual: 63.0;  Predicted: 48.75
# Actual: 56.0;  Predicted: 39.33
# Actual: 77.0;  Predicted: 49.17
# Actual: 86.0;  Predicted: 54.0
# Actual: 76.0;  Predicted: 41.34
#
#
# Epoch 698
#   Train Error: 20.681939860639353
#   Valid Error: 16.227252478738432
#   Train Loss: 645.0133997182377
# Actual: 76.0;  Predicted: 50.91
# Actual: 63.0;  Predicted: 51.1
# Actual: 75.0;  Predicted: 48.94
# Actual: 29.0;  Predicted: 44.46
# Actual: 75.0;  Predicted: 47.54
# Actual: 63.0;  Predicted: 49.17
# Actual: 56.0;  Predicted: 42.03
# Actual: 77.0;  Predicted: 50.11
# Actual: 86.0;  Predicted: 53.65
# Actual: 76.0;  Predicted: 40.82
#
#
# Epoch 699
#   Train Error: 20.704133908119122
#   Valid Error: 19.745604209529542
#   Train Loss: 650.9637015921171
# Actual: 76.0;  Predicted: 53.43
# Actual: 63.0;  Predicted: 53.59
# Actual: 75.0;  Predicted: 51.64
# Actual: 29.0;  Predicted: 46.64
# Actual: 75.0;  Predicted: 49.72
# Actual: 63.0;  Predicted: 51.52
# Actual: 56.0;  Predicted: 43.8
# Actual: 77.0;  Predicted: 52.86
# Actual: 86.0;  Predicted: 56.16
# Actual: 76.0;  Predicted: 43.07
#
#
# Epoch 700
#   Train Error: 20.66847306725389
#   Valid Error: 20.700070649674796
#   Train Loss: 641.1582531538166
# Actual: 76.0;  Predicted: 54.05
# Actual: 63.0;  Predicted: 54.23
# Actual: 75.0;  Predicted: 51.6
# Actual: 29.0;  Predicted: 47.12
# Actual: 75.0;  Predicted: 50.41
# Actual: 63.0;  Predicted: 51.81
# Actual: 56.0;  Predicted: 42.93
# Actual: 77.0;  Predicted: 52.81
# Actual: 86.0;  Predicted: 56.94
# Actual: 76.0;  Predicted: 43.57
#
#
# Epoch 701
#   Train Error: 20.55392957675482
#   Valid Error: 17.282289412415142
#   Train Loss: 641.6318544481621
# Actual: 76.0;  Predicted: 52.26
# Actual: 63.0;  Predicted: 52.49
# Actual: 75.0;  Predicted: 49.79
# Actual: 29.0;  Predicted: 45.63
# Actual: 75.0;  Predicted: 48.78
# Actual: 63.0;  Predicted: 50.02
# Actual: 56.0;  Predicted: 43.53
# Actual: 77.0;  Predicted: 50.43
# Actual: 86.0;  Predicted: 55.09
# Actual: 76.0;  Predicted: 42.03
#
#
# Epoch 702
#   Train Error: 20.6815685700478
#   Valid Error: 17.756710867279942
#   Train Loss: 649.2248680239818
# Actual: 76.0;  Predicted: 52.36
# Actual: 63.0;  Predicted: 52.57
# Actual: 75.0;  Predicted: 50.27
# Actual: 29.0;  Predicted: 45.72
# Actual: 75.0;  Predicted: 48.94
# Actual: 63.0;  Predicted: 50.27
# Actual: 56.0;  Predicted: 42.69
# Actual: 77.0;  Predicted: 50.69
# Actual: 86.0;  Predicted: 55.36
# Actual: 76.0;  Predicted: 42.09
#
#
# Epoch 703
#   Train Error: 20.714701337279003
#   Valid Error: 18.10922096770944
#   Train Loss: 646.2042366403048
# Actual: 76.0;  Predicted: 53.8
# Actual: 63.0;  Predicted: 53.97
# Actual: 75.0;  Predicted: 47.25
# Actual: 29.0;  Predicted: 46.9
# Actual: 75.0;  Predicted: 50.26
# Actual: 63.0;  Predicted: 51.93
# Actual: 56.0;  Predicted: 37.69
# Actual: 77.0;  Predicted: 52.73
# Actual: 86.0;  Predicted: 56.77
# Actual: 76.0;  Predicted: 43.28
#
#
# Epoch 704
#   Train Error: 20.67110550180542
#   Valid Error: 16.39598590887866
#   Train Loss: 652.8181172355277
# Actual: 76.0;  Predicted: 49.59
# Actual: 63.0;  Predicted: 49.75
# Actual: 75.0;  Predicted: 47.42
# Actual: 29.0;  Predicted: 43.24
# Actual: 75.0;  Predicted: 46.33
# Actual: 63.0;  Predicted: 47.64
# Actual: 56.0;  Predicted: 42.17
# Actual: 77.0;  Predicted: 48.26
# Actual: 86.0;  Predicted: 52.3
# Actual: 76.0;  Predicted: 39.88
#
#
# Epoch 705
#   Train Error: 20.762271433015375
#   Valid Error: 17.810770942169487
#   Train Loss: 642.7098108510502
# Actual: 76.0;  Predicted: 54.89
# Actual: 63.0;  Predicted: 54.84
# Actual: 75.0;  Predicted: 52.24
# Actual: 29.0;  Predicted: 47.61
# Actual: 75.0;  Predicted: 51.11
# Actual: 63.0;  Predicted: 51.74
# Actual: 56.0;  Predicted: 44.23
# Actual: 77.0;  Predicted: 53.01
# Actual: 86.0;  Predicted: 58.01
# Actual: 76.0;  Predicted: 44.35
#
#
# Epoch 706
#   Train Error: 20.700855849934218
#   Valid Error: 18.745714687606664
#   Train Loss: 645.015700543513
# Actual: 76.0;  Predicted: 53.22
# Actual: 63.0;  Predicted: 53.28
# Actual: 75.0;  Predicted: 50.4
# Actual: 29.0;  Predicted: 46.27
# Actual: 75.0;  Predicted: 49.62
# Actual: 63.0;  Predicted: 50.65
# Actual: 56.0;  Predicted: 40.79
# Actual: 77.0;  Predicted: 51.59
# Actual: 86.0;  Predicted: 56.16
# Actual: 76.0;  Predicted: 42.96
#
#
# Epoch 707
#   Train Error: 20.5303908960735
#   Valid Error: 17.91084782128195
#   Train Loss: 642.9400129474577
# Actual: 76.0;  Predicted: 54.05
# Actual: 63.0;  Predicted: 53.5
# Actual: 75.0;  Predicted: 50.49
# Actual: 29.0;  Predicted: 46.97
# Actual: 75.0;  Predicted: 50.02
# Actual: 63.0;  Predicted: 50.67
# Actual: 56.0;  Predicted: 43.62
# Actual: 77.0;  Predicted: 50.79
# Actual: 86.0;  Predicted: 56.4
# Actual: 76.0;  Predicted: 43.83
#
#
# Epoch 708
#   Train Error: 20.64440000379408
#   Valid Error: 17.12520417889345
#   Train Loss: 647.9065656818327
# Actual: 76.0;  Predicted: 51.28
# Actual: 63.0;  Predicted: 51.37
# Actual: 75.0;  Predicted: 50.06
# Actual: 29.0;  Predicted: 44.62
# Actual: 75.0;  Predicted: 47.93
# Actual: 63.0;  Predicted: 49.22
# Actual: 56.0;  Predicted: 40.53
# Actual: 77.0;  Predicted: 50.72
# Actual: 86.0;  Predicted: 54.22
# Actual: 76.0;  Predicted: 41.13
#
#
# Epoch 709
#   Train Error: 20.603951698033576
#   Valid Error: 17.973746216412888
#   Train Loss: 644.2021409331775
# Actual: 76.0;  Predicted: 54.47
# Actual: 63.0;  Predicted: 54.52
# Actual: 75.0;  Predicted: 51.46
# Actual: 29.0;  Predicted: 47.38
# Actual: 75.0;  Predicted: 50.78
# Actual: 63.0;  Predicted: 51.35
# Actual: 56.0;  Predicted: 43.37
# Actual: 77.0;  Predicted: 51.62
# Actual: 86.0;  Predicted: 57.36
# Actual: 76.0;  Predicted: 44.04
#
#
# Epoch 710
#   Train Error: 20.63139866692113
#   Valid Error: 18.33881596685613
#   Train Loss: 644.7910176261527
# Actual: 76.0;  Predicted: 53.24
# Actual: 63.0;  Predicted: 53.45
# Actual: 75.0;  Predicted: 50.83
# Actual: 29.0;  Predicted: 46.39
# Actual: 75.0;  Predicted: 49.5
# Actual: 63.0;  Predicted: 50.85
# Actual: 56.0;  Predicted: 42.99
# Actual: 77.0;  Predicted: 51.64
# Actual: 86.0;  Predicted: 55.69
# Actual: 76.0;  Predicted: 42.95
#
#
# Epoch 711
#   Train Error: 20.56143654805459
#   Valid Error: 17.381517910262914
#   Train Loss: 639.787528116195
# Actual: 76.0;  Predicted: 52.19
# Actual: 63.0;  Predicted: 52.39
# Actual: 75.0;  Predicted: 50.66
# Actual: 29.0;  Predicted: 45.54
# Actual: 75.0;  Predicted: 48.66
# Actual: 63.0;  Predicted: 50.76
# Actual: 56.0;  Predicted: 41.77
# Actual: 77.0;  Predicted: 51.33
# Actual: 86.0;  Predicted: 55.03
# Actual: 76.0;  Predicted: 42.01
#
#
# Epoch 712
#   Train Error: 20.572112696086542
#   Valid Error: 16.50532535441871
#   Train Loss: 642.1374061459401
# Actual: 76.0;  Predicted: 48.48
# Actual: 63.0;  Predicted: 48.84
# Actual: 75.0;  Predicted: 46.24
# Actual: 29.0;  Predicted: 42.16
# Actual: 75.0;  Predicted: 45.36
# Actual: 63.0;  Predicted: 46.91
# Actual: 56.0;  Predicted: 36.75
# Actual: 77.0;  Predicted: 47.16
# Actual: 86.0;  Predicted: 51.16
# Actual: 76.0;  Predicted: 37.19
#
#
# Epoch 713
#   Train Error: 20.776083714253193
#   Valid Error: 16.485661108516954
#   Train Loss: 642.328037449571
# Actual: 76.0;  Predicted: 52.61
# Actual: 63.0;  Predicted: 52.84
# Actual: 75.0;  Predicted: 50.49
# Actual: 29.0;  Predicted: 45.99
# Actual: 75.0;  Predicted: 49.08
# Actual: 63.0;  Predicted: 50.8
# Actual: 56.0;  Predicted: 42.76
# Actual: 77.0;  Predicted: 50.83
# Actual: 86.0;  Predicted: 55.39
# Actual: 76.0;  Predicted: 42.43
#
#
# Epoch 714
#   Train Error: 20.645088965084845
#   Valid Error: 19.112972259521484
#   Train Loss: 642.741162909836
# Actual: 76.0;  Predicted: 53.15
# Actual: 63.0;  Predicted: 53.36
# Actual: 75.0;  Predicted: 52.2
# Actual: 29.0;  Predicted: 46.39
# Actual: 75.0;  Predicted: 49.75
# Actual: 63.0;  Predicted: 52.41
# Actual: 56.0;  Predicted: 43.13
# Actual: 77.0;  Predicted: 52.98
# Actual: 86.0;  Predicted: 56.43
# Actual: 76.0;  Predicted: 42.72
#
#
# Epoch 715
#   Train Error: 20.6260700899945
#   Valid Error: 18.177201872890436
#   Train Loss: 639.5277805015689
# Actual: 76.0;  Predicted: 56.07
# Actual: 63.0;  Predicted: 55.53
# Actual: 75.0;  Predicted: 52.43
# Actual: 29.0;  Predicted: 48.77
# Actual: 75.0;  Predicted: 51.76
# Actual: 63.0;  Predicted: 52.62
# Actual: 56.0;  Predicted: 42.92
# Actual: 77.0;  Predicted: 53.1
# Actual: 86.0;  Predicted: 58.57
# Actual: 76.0;  Predicted: 45.57
#
#
# Epoch 716
#   Train Error: 20.61776028353558
#   Valid Error: 19.741867509860437
#   Train Loss: 647.6977784203701
# Actual: 76.0;  Predicted: 56.62
# Actual: 63.0;  Predicted: 55.28
# Actual: 75.0;  Predicted: 52.51
# Actual: 29.0;  Predicted: 49.17
# Actual: 75.0;  Predicted: 51.81
# Actual: 63.0;  Predicted: 51.71
# Actual: 56.0;  Predicted: 46.74
# Actual: 77.0;  Predicted: 53.64
# Actual: 86.0;  Predicted: 58.71
# Actual: 76.0;  Predicted: 46.1
#
#
# Epoch 717
#   Train Error: 20.637821245094347
#   Valid Error: 16.32272894405624
#   Train Loss: 640.081835137039
# Actual: 76.0;  Predicted: 53.36
# Actual: 63.0;  Predicted: 53.54
# Actual: 75.0;  Predicted: 50.78
# Actual: 29.0;  Predicted: 46.52
# Actual: 75.0;  Predicted: 49.71
# Actual: 63.0;  Predicted: 51.18
# Actual: 56.0;  Predicted: 41.44
# Actual: 77.0;  Predicted: 52.27
# Actual: 86.0;  Predicted: 56.32
# Actual: 76.0;  Predicted: 43.11
#
#
# Epoch 718
#   Train Error: 20.627291078626985
#   Valid Error: 19.34977781425402
#   Train Loss: 648.0207164326653
# Actual: 76.0;  Predicted: 53.2
# Actual: 63.0;  Predicted: 53.27
# Actual: 75.0;  Predicted: 49.95
# Actual: 29.0;  Predicted: 46.32
# Actual: 75.0;  Predicted: 49.6
# Actual: 63.0;  Predicted: 50.44
# Actual: 56.0;  Predicted: 41.9
# Actual: 77.0;  Predicted: 50.65
# Actual: 86.0;  Predicted: 56.0
# Actual: 76.0;  Predicted: 43.04
#
#
# Epoch 719
#   Train Error: 20.713701426611124
#   Valid Error: 19.854825769813317
#   Train Loss: 648.9844030161373
# Actual: 76.0;  Predicted: 52.26
# Actual: 63.0;  Predicted: 52.45
# Actual: 75.0;  Predicted: 49.64
# Actual: 29.0;  Predicted: 45.56
# Actual: 75.0;  Predicted: 48.57
# Actual: 63.0;  Predicted: 49.66
# Actual: 56.0;  Predicted: 40.84
# Actual: 77.0;  Predicted: 50.28
# Actual: 86.0;  Predicted: 54.73
# Actual: 76.0;  Predicted: 42.24
#
#
# Epoch 720
#   Train Error: 20.622353083874234
#   Valid Error: 18.056663772434863
#   Train Loss: 642.8053363737513
# Actual: 76.0;  Predicted: 53.36
# Actual: 63.0;  Predicted: 53.04
# Actual: 75.0;  Predicted: 49.29
# Actual: 29.0;  Predicted: 46.48
# Actual: 75.0;  Predicted: 49.64
# Actual: 63.0;  Predicted: 49.93
# Actual: 56.0;  Predicted: 38.7
# Actual: 77.0;  Predicted: 50.85
# Actual: 86.0;  Predicted: 56.23
# Actual: 76.0;  Predicted: 43.22
#
#
# Epoch 721
#   Train Error: 20.637165442325966
#   Valid Error: 19.85149768718238
#   Train Loss: 641.0119018554688
# Actual: 76.0;  Predicted: 53.53
# Actual: 63.0;  Predicted: 53.37
# Actual: 75.0;  Predicted: 50.83
# Actual: 29.0;  Predicted: 46.28
# Actual: 75.0;  Predicted: 49.91
# Actual: 63.0;  Predicted: 50.24
# Actual: 56.0;  Predicted: 42.14
# Actual: 77.0;  Predicted: 51.26
# Actual: 86.0;  Predicted: 56.37
# Actual: 76.0;  Predicted: 43.01
#
#
# Epoch 722
#   Train Error: 20.537044683761756
#   Valid Error: 14.26081570375313
#   Train Loss: 649.052019963499
# Actual: 76.0;  Predicted: 48.8
# Actual: 63.0;  Predicted: 49.13
# Actual: 75.0;  Predicted: 46.17
# Actual: 29.0;  Predicted: 42.63
# Actual: 75.0;  Predicted: 45.5
# Actual: 63.0;  Predicted: 47.4
# Actual: 56.0;  Predicted: 36.44
# Actual: 77.0;  Predicted: 47.74
# Actual: 86.0;  Predicted: 51.26
# Actual: 76.0;  Predicted: 39.11
#
#
# Epoch 723
#   Train Error: 20.66173356585592
#   Valid Error: 21.973813140276565
#   Train Loss: 637.749674312404
# Actual: 76.0;  Predicted: 53.53
# Actual: 63.0;  Predicted: 53.62
# Actual: 75.0;  Predicted: 50.84
# Actual: 29.0;  Predicted: 46.56
# Actual: 75.0;  Predicted: 49.95
# Actual: 63.0;  Predicted: 51.06
# Actual: 56.0;  Predicted: 43.74
# Actual: 77.0;  Predicted: 51.8
# Actual: 86.0;  Predicted: 56.42
# Actual: 76.0;  Predicted: 43.25
#
#
# Epoch 724
#   Train Error: 20.557470210624583
#   Valid Error: 18.174466364592025
#   Train Loss: 647.4772574002626
# Actual: 76.0;  Predicted: 53.67
# Actual: 63.0;  Predicted: 53.6
# Actual: 75.0;  Predicted: 50.26
# Actual: 29.0;  Predicted: 46.51
# Actual: 75.0;  Predicted: 50.14
# Actual: 63.0;  Predicted: 50.89
# Actual: 56.0;  Predicted: 39.24
# Actual: 77.0;  Predicted: 51.9
# Actual: 86.0;  Predicted: 56.93
# Actual: 76.0;  Predicted: 43.16
#
#
# Epoch 725
#   Train Error: 20.59499668827176
#   Valid Error: 19.292396360230676
#   Train Loss: 639.5510969318327
# Actual: 76.0;  Predicted: 53.95
# Actual: 63.0;  Predicted: 53.16
# Actual: 75.0;  Predicted: 50.64
# Actual: 29.0;  Predicted: 46.87
# Actual: 75.0;  Predicted: 49.85
# Actual: 63.0;  Predicted: 50.47
# Actual: 56.0;  Predicted: 40.74
# Actual: 77.0;  Predicted: 50.78
# Actual: 86.0;  Predicted: 56.51
# Actual: 76.0;  Predicted: 43.71
#
#
# Epoch 726
#   Train Error: 20.71665706753483
#   Valid Error: 14.927665228982574
#   Train Loss: 648.1717269147028
# Actual: 76.0;  Predicted: 52.0
# Actual: 63.0;  Predicted: 52.14
# Actual: 75.0;  Predicted: 50.08
# Actual: 29.0;  Predicted: 45.31
# Actual: 75.0;  Predicted: 48.6
# Actual: 63.0;  Predicted: 50.28
# Actual: 56.0;  Predicted: 40.57
# Actual: 77.0;  Predicted: 50.62
# Actual: 86.0;  Predicted: 54.98
# Actual: 76.0;  Predicted: 41.91
#
#
# Epoch 727
#   Train Error: 20.648229938039165
#   Valid Error: 19.652184680827613
#   Train Loss: 638.5308950455462
# Actual: 76.0;  Predicted: 54.23
# Actual: 63.0;  Predicted: 54.26
# Actual: 75.0;  Predicted: 51.88
# Actual: 29.0;  Predicted: 47.17
# Actual: 75.0;  Predicted: 50.59
# Actual: 63.0;  Predicted: 51.78
# Actual: 56.0;  Predicted: 43.57
# Actual: 77.0;  Predicted: 52.87
# Actual: 86.0;  Predicted: 57.31
# Actual: 76.0;  Predicted: 43.85
#
#
# Epoch 728
#   Train Error: 20.59722645416577
#   Valid Error: 21.116144939533715
#   Train Loss: 653.1342628353932
# Actual: 76.0;  Predicted: 52.04
# Actual: 63.0;  Predicted: 52.17
# Actual: 75.0;  Predicted: 49.07
# Actual: 29.0;  Predicted: 45.36
# Actual: 75.0;  Predicted: 48.41
# Actual: 63.0;  Predicted: 49.37
# Actual: 56.0;  Predicted: 42.18
# Actual: 77.0;  Predicted: 50.2
# Actual: 86.0;  Predicted: 54.65
# Actual: 76.0;  Predicted: 42.09
#
#
# Epoch 729
#   Train Error: 20.637512425127248
#   Valid Error: 19.45298089332951
#   Train Loss: 644.1419022356878
# Actual: 76.0;  Predicted: 54.93
# Actual: 63.0;  Predicted: 53.85
# Actual: 75.0;  Predicted: 49.77
# Actual: 29.0;  Predicted: 47.62
# Actual: 75.0;  Predicted: 50.46
# Actual: 63.0;  Predicted: 51.36
# Actual: 56.0;  Predicted: 39.82
# Actual: 77.0;  Predicted: 51.63
# Actual: 86.0;  Predicted: 57.01
# Actual: 76.0;  Predicted: 44.54
#
#
# Epoch 730
#   Train Error: 20.570493472093357
#   Valid Error: 18.48496357445578
#   Train Loss: 640.1525653776575
# Actual: 76.0;  Predicted: 51.74
# Actual: 63.0;  Predicted: 51.87
# Actual: 75.0;  Predicted: 49.58
# Actual: 29.0;  Predicted: 45.04
# Actual: 75.0;  Predicted: 48.14
# Actual: 63.0;  Predicted: 50.06
# Actual: 56.0;  Predicted: 40.39
# Actual: 77.0;  Predicted: 49.33
# Actual: 86.0;  Predicted: 54.27
# Actual: 76.0;  Predicted: 41.69
#
#
# Epoch 731
#   Train Error: 20.65703801851015
#   Valid Error: 18.82780849123464
#   Train Loss: 637.0386292504483
# Actual: 76.0;  Predicted: 55.24
# Actual: 63.0;  Predicted: 55.18
# Actual: 75.0;  Predicted: 52.97
# Actual: 29.0;  Predicted: 47.93
# Actual: 75.0;  Predicted: 51.32
# Actual: 63.0;  Predicted: 52.19
# Actual: 56.0;  Predicted: 48.32
# Actual: 77.0;  Predicted: 54.22
# Actual: 86.0;  Predicted: 58.26
# Actual: 76.0;  Predicted: 44.83
#
#
# Epoch 732
#   Train Error: 20.58441000718337
#   Valid Error: 21.235717847509292
#   Train Loss: 636.9266172315254
# Actual: 76.0;  Predicted: 55.19
# Actual: 63.0;  Predicted: 55.2
# Actual: 75.0;  Predicted: 52.17
# Actual: 29.0;  Predicted: 47.94
# Actual: 75.0;  Predicted: 51.18
# Actual: 63.0;  Predicted: 52.36
# Actual: 56.0;  Predicted: 44.51
# Actual: 77.0;  Predicted: 53.14
# Actual: 86.0;  Predicted: 57.7
# Actual: 76.0;  Predicted: 44.76
#
#
# Epoch 733
#   Train Error: 20.608613182749917
#   Valid Error: 17.3167794977577
#   Train Loss: 648.5738185194672
# Actual: 76.0;  Predicted: 49.06
# Actual: 63.0;  Predicted: 49.27
# Actual: 75.0;  Predicted: 47.01
# Actual: 29.0;  Predicted: 42.82
# Actual: 75.0;  Predicted: 45.77
# Actual: 63.0;  Predicted: 47.39
# Actual: 56.0;  Predicted: 37.89
# Actual: 77.0;  Predicted: 47.21
# Actual: 86.0;  Predicted: 51.63
# Actual: 76.0;  Predicted: 39.42
#
#
# Epoch 734
#   Train Error: 20.63021610283802
#   Valid Error: 16.63016780371805
#   Train Loss: 646.1017396020108
# Actual: 76.0;  Predicted: 52.5
# Actual: 63.0;  Predicted: 51.72
# Actual: 75.0;  Predicted: 49.01
# Actual: 29.0;  Predicted: 45.61
# Actual: 75.0;  Predicted: 48.39
# Actual: 63.0;  Predicted: 49.34
# Actual: 56.0;  Predicted: 40.24
# Actual: 77.0;  Predicted: 50.43
# Actual: 86.0;  Predicted: 54.9
# Actual: 76.0;  Predicted: 42.63
#
#
# Epoch 735
#   Train Error: 20.705167780299195
#   Valid Error: 18.767300726140586
#   Train Loss: 637.4074917152279
# Actual: 76.0;  Predicted: 52.88
# Actual: 63.0;  Predicted: 52.91
# Actual: 75.0;  Predicted: 50.11
# Actual: 29.0;  Predicted: 45.97
# Actual: 75.0;  Predicted: 49.13
# Actual: 63.0;  Predicted: 51.17
# Actual: 56.0;  Predicted: 40.33
# Actual: 77.0;  Predicted: 50.4
# Actual: 86.0;  Predicted: 55.49
# Actual: 76.0;  Predicted: 42.72
#
#
# Epoch 736
#   Train Error: 20.62298335751476
#   Valid Error: 17.637682794367226
#   Train Loss: 643.090630202997
# Actual: 76.0;  Predicted: 53.66
# Actual: 63.0;  Predicted: 53.45
# Actual: 75.0;  Predicted: 50.53
# Actual: 29.0;  Predicted: 46.64
# Actual: 75.0;  Predicted: 50.0
# Actual: 63.0;  Predicted: 50.81
# Actual: 56.0;  Predicted: 41.1
# Actual: 77.0;  Predicted: 51.14
# Actual: 86.0;  Predicted: 56.47
# Actual: 76.0;  Predicted: 43.5
#
#
# Epoch 737
#   Train Error: 20.518776649744744
#   Valid Error: 17.242864479139012
#   Train Loss: 647.2867391617572
# Actual: 76.0;  Predicted: 49.25
# Actual: 63.0;  Predicted: 49.5
# Actual: 75.0;  Predicted: 48.48
# Actual: 29.0;  Predicted: 43.04
# Actual: 75.0;  Predicted: 46.02
# Actual: 63.0;  Predicted: 48.88
# Actual: 56.0;  Predicted: 42.23
# Actual: 77.0;  Predicted: 48.88
# Actual: 86.0;  Predicted: 52.08
# Actual: 76.0;  Predicted: 39.56
#
#
# Epoch 738
#   Train Error: 20.616477724420307
#   Valid Error: 16.566403731559088
#   Train Loss: 643.9895024534131
# Actual: 76.0;  Predicted: 51.79
# Actual: 63.0;  Predicted: 51.86
# Actual: 75.0;  Predicted: 49.44
# Actual: 29.0;  Predicted: 45.09
# Actual: 75.0;  Predicted: 48.16
# Actual: 63.0;  Predicted: 49.72
# Actual: 56.0;  Predicted: 40.67
# Actual: 77.0;  Predicted: 50.21
# Actual: 86.0;  Predicted: 54.36
# Actual: 76.0;  Predicted: 41.79
#
#
# Epoch 739
#   Train Error: 20.698045248796934
#   Valid Error: 16.94979421374867
#   Train Loss: 636.4224203141009
# Actual: 76.0;  Predicted: 57.28
# Actual: 63.0;  Predicted: 55.59
# Actual: 75.0;  Predicted: 52.19
# Actual: 29.0;  Predicted: 49.38
# Actual: 75.0;  Predicted: 52.43
# Actual: 63.0;  Predicted: 52.13
# Actual: 56.0;  Predicted: 40.7
# Actual: 77.0;  Predicted: 53.23
# Actual: 86.0;  Predicted: 59.32
# Actual: 76.0;  Predicted: 46.39
#
#
# Epoch 740
#   Train Error: 20.574922629057
#   Valid Error: 18.108189110617037
#   Train Loss: 646.5895926053407
# Actual: 76.0;  Predicted: 52.14
# Actual: 63.0;  Predicted: 52.18
# Actual: 75.0;  Predicted: 49.84
# Actual: 29.0;  Predicted: 45.38
# Actual: 75.0;  Predicted: 48.68
# Actual: 63.0;  Predicted: 50.15
# Actual: 56.0;  Predicted: 41.74
# Actual: 77.0;  Predicted: 50.36
# Actual: 86.0;  Predicted: 55.02
# Actual: 76.0;  Predicted: 42.05
#
#
# Epoch 741
#   Train Error: 20.66232681274414
#   Valid Error: 18.672566534246055
#   Train Loss: 644.4219180247823
# Actual: 76.0;  Predicted: 52.55
# Actual: 63.0;  Predicted: 52.65
# Actual: 75.0;  Predicted: 50.08
# Actual: 29.0;  Predicted: 45.78
# Actual: 75.0;  Predicted: 49.09
# Actual: 63.0;  Predicted: 50.99
# Actual: 56.0;  Predicted: 40.09
# Actual: 77.0;  Predicted: 50.57
# Actual: 86.0;  Predicted: 55.52
# Actual: 76.0;  Predicted: 42.36
#
#
# Epoch 742
#   Train Error: 20.534670716759567
#   Valid Error: 19.508193784547082
#   Train Loss: 645.6125288165983
# Actual: 76.0;  Predicted: 51.33
# Actual: 63.0;  Predicted: 51.46
# Actual: 75.0;  Predicted: 48.78
# Actual: 29.0;  Predicted: 44.77
# Actual: 75.0;  Predicted: 47.73
# Actual: 63.0;  Predicted: 49.21
# Actual: 56.0;  Predicted: 41.14
# Actual: 77.0;  Predicted: 49.23
# Actual: 86.0;  Predicted: 53.88
# Actual: 76.0;  Predicted: 41.4
#
#
# Epoch 743
#   Train Error: 20.589201849860114
#   Valid Error: 16.464018516170167
#   Train Loss: 638.8050512094967
# Actual: 76.0;  Predicted: 50.85
# Actual: 63.0;  Predicted: 50.7
# Actual: 75.0;  Predicted: 49.03
# Actual: 29.0;  Predicted: 44.07
# Actual: 75.0;  Predicted: 47.54
# Actual: 63.0;  Predicted: 48.5
# Actual: 56.0;  Predicted: 37.81
# Actual: 77.0;  Predicted: 49.31
# Actual: 86.0;  Predicted: 53.71
# Actual: 76.0;  Predicted: 40.6
#
#
# Epoch 744
#   Train Error: 20.596992389575856
#   Valid Error: 18.83341072601022
#   Train Loss: 639.0195607670018
# Actual: 76.0;  Predicted: 56.0
# Actual: 63.0;  Predicted: 55.09
# Actual: 75.0;  Predicted: 49.99
# Actual: 29.0;  Predicted: 48.59
# Actual: 75.0;  Predicted: 51.59
# Actual: 63.0;  Predicted: 52.4
# Actual: 56.0;  Predicted: 40.6
# Actual: 77.0;  Predicted: 53.37
# Actual: 86.0;  Predicted: 58.23
# Actual: 76.0;  Predicted: 45.56
#
#
# Epoch 745
#   Train Error: 20.641540852505056
#   Valid Error: 17.774849234275447
#   Train Loss: 645.0807940373655
# Actual: 76.0;  Predicted: 52.04
# Actual: 63.0;  Predicted: 52.06
# Actual: 75.0;  Predicted: 50.31
# Actual: 29.0;  Predicted: 45.28
# Actual: 75.0;  Predicted: 48.58
# Actual: 63.0;  Predicted: 49.96
# Actual: 56.0;  Predicted: 41.49
# Actual: 77.0;  Predicted: 51.17
# Actual: 86.0;  Predicted: 55.18
# Actual: 76.0;  Predicted: 41.97
#
#
# Epoch 746
#   Train Error: 20.650475404862306
#   Valid Error: 18.484483070743895
#   Train Loss: 648.3734005787334
# Actual: 76.0;  Predicted: 55.2
# Actual: 63.0;  Predicted: 53.75
# Actual: 75.0;  Predicted: 51.22
# Actual: 29.0;  Predicted: 47.75
# Actual: 75.0;  Predicted: 50.57
# Actual: 63.0;  Predicted: 50.84
# Actual: 56.0;  Predicted: 41.38
# Actual: 77.0;  Predicted: 51.26
# Actual: 86.0;  Predicted: 57.27
# Actual: 76.0;  Predicted: 44.69
#
#
# Epoch 747
#   Train Error: 20.575306636627896
#   Valid Error: 17.437711919395667
#   Train Loss: 646.8089749695824
# Actual: 76.0;  Predicted: 54.97
# Actual: 63.0;  Predicted: 54.11
# Actual: 75.0;  Predicted: 48.22
# Actual: 29.0;  Predicted: 47.19
# Actual: 75.0;  Predicted: 51.13
# Actual: 63.0;  Predicted: 49.7
# Actual: 56.0;  Predicted: 36.72
# Actual: 77.0;  Predicted: 50.83
# Actual: 86.0;  Predicted: 58.08
# Actual: 76.0;  Predicted: 44.05
#
#
# Epoch 748
#   Train Error: 20.61722221295204
#   Valid Error: 19.184645902763293
#   Train Loss: 641.06439309042
# Actual: 76.0;  Predicted: 52.78
# Actual: 63.0;  Predicted: 52.86
# Actual: 75.0;  Predicted: 51.0
# Actual: 29.0;  Predicted: 45.96
# Actual: 75.0;  Predicted: 49.06
# Actual: 63.0;  Predicted: 51.36
# Actual: 56.0;  Predicted: 44.09
# Actual: 77.0;  Predicted: 51.01
# Actual: 86.0;  Predicted: 55.49
# Actual: 76.0;  Predicted: 42.53
#
#
# Epoch 749
#   Train Error: 20.61083836862798
#   Valid Error: 20.72655783347713
#   Train Loss: 637.4673166744044
# Actual: 76.0;  Predicted: 52.95
# Actual: 63.0;  Predicted: 52.98
# Actual: 75.0;  Predicted: 50.51
# Actual: 29.0;  Predicted: 46.06
# Actual: 75.0;  Predicted: 49.34
# Actual: 63.0;  Predicted: 50.96
# Actual: 56.0;  Predicted: 42.11
# Actual: 77.0;  Predicted: 51.19
# Actual: 86.0;  Predicted: 55.72
# Actual: 76.0;  Predicted: 42.73
#
#
# Epoch 750
#   Train Error: 20.44003887533398
#   Valid Error: 17.820479494854084
#   Train Loss: 638.9686119204662
# Actual: 76.0;  Predicted: 50.09
# Actual: 63.0;  Predicted: 50.29
# Actual: 75.0;  Predicted: 49.27
# Actual: 29.0;  Predicted: 43.71
# Actual: 75.0;  Predicted: 46.88
# Actual: 63.0;  Predicted: 49.31
# Actual: 56.0;  Predicted: 40.64
# Actual: 77.0;  Predicted: 49.95
# Actual: 86.0;  Predicted: 52.95
# Actual: 76.0;  Predicted: 40.16
#
#
# Epoch 751
#   Train Error: 20.66149052165898
#   Valid Error: 19.903744077219546
#   Train Loss: 640.9799409459849
# Actual: 76.0;  Predicted: 50.34
# Actual: 63.0;  Predicted: 50.66
# Actual: 75.0;  Predicted: 47.17
# Actual: 29.0;  Predicted: 44.0
# Actual: 75.0;  Predicted: 47.03
# Actual: 63.0;  Predicted: 49.57
# Actual: 56.0;  Predicted: 37.59
# Actual: 77.0;  Predicted: 50.13
# Actual: 86.0;  Predicted: 53.07
# Actual: 76.0;  Predicted: 40.37
#
#
# Epoch 752
#   Train Error: 20.552492792046245
#   Valid Error: 19.203301550115196
#   Train Loss: 638.3482235767802
# Actual: 76.0;  Predicted: 51.91
# Actual: 63.0;  Predicted: 52.02
# Actual: 75.0;  Predicted: 49.62
# Actual: 29.0;  Predicted: 45.19
# Actual: 75.0;  Predicted: 48.27
# Actual: 63.0;  Predicted: 49.94
# Actual: 56.0;  Predicted: 40.01
# Actual: 77.0;  Predicted: 50.16
# Actual: 86.0;  Predicted: 54.51
# Actual: 76.0;  Predicted: 41.8
#
#
# Epoch 753
#   Train Error: 20.57817320318083
#   Valid Error: 18.112047769490953
#   Train Loss: 642.9444004746734
# Actual: 76.0;  Predicted: 51.33
# Actual: 63.0;  Predicted: 51.51
# Actual: 75.0;  Predicted: 49.14
# Actual: 29.0;  Predicted: 44.68
# Actual: 75.0;  Predicted: 47.77
# Actual: 63.0;  Predicted: 49.49
# Actual: 56.0;  Predicted: 40.8
# Actual: 77.0;  Predicted: 48.75
# Actual: 86.0;  Predicted: 54.07
# Actual: 76.0;  Predicted: 41.31
#
#
# Epoch 754
#   Train Error: 20.64469303757634
#   Valid Error: 18.136273911855753
#   Train Loss: 648.3665156129931
# Actual: 76.0;  Predicted: 49.07
# Actual: 63.0;  Predicted: 49.42
# Actual: 75.0;  Predicted: 47.32
# Actual: 29.0;  Predicted: 42.91
# Actual: 75.0;  Predicted: 45.83
# Actual: 63.0;  Predicted: 48.81
# Actual: 56.0;  Predicted: 37.47
# Actual: 77.0;  Predicted: 48.08
# Actual: 86.0;  Predicted: 51.86
# Actual: 76.0;  Predicted: 39.19
#
#
# Epoch 755
#   Train Error: 20.57231737323214
#   Valid Error: 18.189262241993134
#   Train Loss: 644.9194055776127
# Actual: 76.0;  Predicted: 53.74
# Actual: 63.0;  Predicted: 53.13
# Actual: 75.0;  Predicted: 50.06
# Actual: 29.0;  Predicted: 46.78
# Actual: 75.0;  Predicted: 49.62
# Actual: 63.0;  Predicted: 50.46
# Actual: 56.0;  Predicted: 42.06
# Actual: 77.0;  Predicted: 50.65
# Actual: 86.0;  Predicted: 56.01
# Actual: 76.0;  Predicted: 43.44
#
#
# Epoch 756
#   Train Error: 20.608710921479858
#   Valid Error: 19.42951020916689
#   Train Loss: 639.2901331166752
# Actual: 76.0;  Predicted: 52.23
# Actual: 63.0;  Predicted: 52.15
# Actual: 75.0;  Predicted: 50.77
# Actual: 29.0;  Predicted: 45.29
# Actual: 75.0;  Predicted: 48.86
# Actual: 63.0;  Predicted: 49.78
# Actual: 56.0;  Predicted: 40.0
# Actual: 77.0;  Predicted: 50.49
# Actual: 86.0;  Predicted: 55.49
# Actual: 76.0;  Predicted: 41.65
#
#
# Epoch 757
#   Train Error: 20.641930395748908
#   Valid Error: 16.721162147892333
#   Train Loss: 649.8241156906378
# Actual: 76.0;  Predicted: 56.52
# Actual: 63.0;  Predicted: 55.48
# Actual: 75.0;  Predicted: 51.95
# Actual: 29.0;  Predicted: 49.31
# Actual: 75.0;  Predicted: 51.73
# Actual: 63.0;  Predicted: 52.22
# Actual: 56.0;  Predicted: 41.79
# Actual: 77.0;  Predicted: 52.59
# Actual: 86.0;  Predicted: 58.25
# Actual: 76.0;  Predicted: 45.74
#
#
# Epoch 758
#   Train Error: 20.6015735078998
#   Valid Error: 18.09003492929403
#   Train Loss: 639.9831658035029
# Actual: 76.0;  Predicted: 51.16
# Actual: 63.0;  Predicted: 51.22
# Actual: 75.0;  Predicted: 49.64
# Actual: 29.0;  Predicted: 44.49
# Actual: 75.0;  Predicted: 47.88
# Actual: 63.0;  Predicted: 49.96
# Actual: 56.0;  Predicted: 42.38
# Actual: 77.0;  Predicted: 50.03
# Actual: 86.0;  Predicted: 54.06
# Actual: 76.0;  Predicted: 40.88
#
#
# Epoch 759
#   Train Error: 20.622169244809854
#   Valid Error: 17.56290072839237
#   Train Loss: 638.0698742475666
# Actual: 76.0;  Predicted: 52.95
# Actual: 63.0;  Predicted: 52.83
# Actual: 75.0;  Predicted: 50.51
# Actual: 29.0;  Predicted: 45.88
# Actual: 75.0;  Predicted: 49.45
# Actual: 63.0;  Predicted: 50.22
# Actual: 56.0;  Predicted: 39.81
# Actual: 77.0;  Predicted: 50.29
# Actual: 86.0;  Predicted: 55.9
# Actual: 76.0;  Predicted: 42.5
#
#
# Epoch 760
#   Train Error: 20.469124740473692
#   Valid Error: 19.05453583800677
#   Train Loss: 636.7863159179688
# Actual: 76.0;  Predicted: 48.57
# Actual: 63.0;  Predicted: 48.87
# Actual: 75.0;  Predicted: 48.02
# Actual: 29.0;  Predicted: 42.43
# Actual: 75.0;  Predicted: 45.34
# Actual: 63.0;  Predicted: 48.14
# Actual: 56.0;  Predicted: 40.04
# Actual: 77.0;  Predicted: 48.19
# Actual: 86.0;  Predicted: 51.01
# Actual: 76.0;  Predicted: 38.61
#
#
# Epoch 761
#   Train Error: 20.644506387056282
#   Valid Error: 19.312718104390264
#   Train Loss: 643.5158236144019
# Actual: 76.0;  Predicted: 52.42
# Actual: 63.0;  Predicted: 52.54
# Actual: 75.0;  Predicted: 50.19
# Actual: 29.0;  Predicted: 45.62
# Actual: 75.0;  Predicted: 48.89
# Actual: 63.0;  Predicted: 50.5
# Actual: 56.0;  Predicted: 41.02
# Actual: 77.0;  Predicted: 50.87
# Actual: 86.0;  Predicted: 55.24
# Actual: 76.0;  Predicted: 42.13
#
#
# Epoch 762
#   Train Error: 20.518782776259584
#   Valid Error: 17.75600129655264
#   Train Loss: 639.331931692655
# Actual: 76.0;  Predicted: 50.19
# Actual: 63.0;  Predicted: 50.38
# Actual: 75.0;  Predicted: 47.47
# Actual: 29.0;  Predicted: 43.69
# Actual: 75.0;  Predicted: 46.77
# Actual: 63.0;  Predicted: 49.1
# Actual: 56.0;  Predicted: 37.68
# Actual: 77.0;  Predicted: 48.38
# Actual: 86.0;  Predicted: 52.96
# Actual: 76.0;  Predicted: 40.06
#
#
# Epoch 763
#   Train Error: 20.563841611580642
#   Valid Error: 18.38534497751773
#   Train Loss: 641.8467347191983
# Actual: 76.0;  Predicted: 52.51
# Actual: 63.0;  Predicted: 52.78
# Actual: 75.0;  Predicted: 50.11
# Actual: 29.0;  Predicted: 45.99
# Actual: 75.0;  Predicted: 48.87
# Actual: 63.0;  Predicted: 50.43
# Actual: 56.0;  Predicted: 41.27
# Actual: 77.0;  Predicted: 50.65
# Actual: 86.0;  Predicted: 55.2
# Actual: 76.0;  Predicted: 42.23
#
#
# Epoch 764
#   Train Error: 20.532306599765707
#   Valid Error: 17.251506953563506
#   Train Loss: 636.3737522813141
# Actual: 76.0;  Predicted: 50.04
# Actual: 63.0;  Predicted: 50.34
# Actual: 75.0;  Predicted: 48.23
# Actual: 29.0;  Predicted: 43.9
# Actual: 75.0;  Predicted: 46.67
# Actual: 63.0;  Predicted: 48.59
# Actual: 56.0;  Predicted: 39.31
# Actual: 77.0;  Predicted: 48.24
# Actual: 86.0;  Predicted: 52.69
# Actual: 76.0;  Predicted: 40.12
#
#
# Epoch 765
#   Train Error: 20.555895446491835
#   Valid Error: 19.490548957898778
#   Train Loss: 643.6459190493724
# Actual: 76.0;  Predicted: 53.75
# Actual: 63.0;  Predicted: 53.52
# Actual: 75.0;  Predicted: 50.67
# Actual: 29.0;  Predicted: 46.66
# Actual: 75.0;  Predicted: 50.17
# Actual: 63.0;  Predicted: 50.68
# Actual: 56.0;  Predicted: 39.83
# Actual: 77.0;  Predicted: 51.44
# Actual: 86.0;  Predicted: 56.69
# Actual: 76.0;  Predicted: 43.26
#
#
# Epoch 766
#   Train Error: 20.616324470345543
#   Valid Error: 21.24352708835046
#   Train Loss: 637.813826263928
# Actual: 76.0;  Predicted: 52.44
# Actual: 63.0;  Predicted: 52.59
# Actual: 75.0;  Predicted: 49.66
# Actual: 29.0;  Predicted: 45.67
# Actual: 75.0;  Predicted: 48.86
# Actual: 63.0;  Predicted: 50.31
# Actual: 56.0;  Predicted: 39.91
# Actual: 77.0;  Predicted: 50.77
# Actual: 86.0;  Predicted: 55.18
# Actual: 76.0;  Predicted: 42.15
#
#
# Epoch 767
#   Train Error: 20.54887735521471
#   Valid Error: 18.38930411477691
#   Train Loss: 639.3451463042712
# Actual: 76.0;  Predicted: 53.15
# Actual: 63.0;  Predicted: 52.57
# Actual: 75.0;  Predicted: 50.06
# Actual: 29.0;  Predicted: 46.22
# Actual: 75.0;  Predicted: 49.29
# Actual: 63.0;  Predicted: 50.17
# Actual: 56.0;  Predicted: 40.15
# Actual: 77.0;  Predicted: 49.6
# Actual: 86.0;  Predicted: 55.75
# Actual: 76.0;  Predicted: 43.01
#
#
# Epoch 768
#   Train Error: 20.540700737998787
#   Valid Error: 19.309317875834346
#   Train Loss: 648.5554244244685
# Actual: 76.0;  Predicted: 51.91
# Actual: 63.0;  Predicted: 52.06
# Actual: 75.0;  Predicted: 49.74
# Actual: 29.0;  Predicted: 45.22
# Actual: 75.0;  Predicted: 48.31
# Actual: 63.0;  Predicted: 50.08
# Actual: 56.0;  Predicted: 39.86
# Actual: 77.0;  Predicted: 50.01
# Actual: 86.0;  Predicted: 54.54
# Actual: 76.0;  Predicted: 41.78
#
#
# Epoch 769
#   Train Error: 20.600401368805375
#   Valid Error: 20.52929494913342
#   Train Loss: 641.0715987408747
# Actual: 76.0;  Predicted: 51.15
# Actual: 63.0;  Predicted: 51.47
# Actual: 75.0;  Predicted: 49.34
# Actual: 29.0;  Predicted: 44.66
# Actual: 75.0;  Predicted: 47.7
# Actual: 63.0;  Predicted: 49.96
# Actual: 56.0;  Predicted: 39.55
# Actual: 77.0;  Predicted: 50.2
# Actual: 86.0;  Predicted: 53.82
# Actual: 76.0;  Predicted: 41.02
#
#
# Epoch 770
#   Train Error: 20.592494112042527
#   Valid Error: 19.14971731241467
#   Train Loss: 645.7730117547708
# Actual: 76.0;  Predicted: 52.4
# Actual: 63.0;  Predicted: 51.89
# Actual: 75.0;  Predicted: 49.69
# Actual: 29.0;  Predicted: 45.53
# Actual: 75.0;  Predicted: 48.53
# Actual: 63.0;  Predicted: 49.89
# Actual: 56.0;  Predicted: 41.08
# Actual: 77.0;  Predicted: 50.27
# Actual: 86.0;  Predicted: 55.03
# Actual: 76.0;  Predicted: 42.18
#
#
# Epoch 771
#   Train Error: 20.704349299726267
#   Valid Error: 21.88488828788683
#   Train Loss: 644.2161535044186
# Actual: 76.0;  Predicted: 54.49
# Actual: 63.0;  Predicted: 52.97
# Actual: 75.0;  Predicted: 50.65
# Actual: 29.0;  Predicted: 47.19
# Actual: 75.0;  Predicted: 49.91
# Actual: 63.0;  Predicted: 49.57
# Actual: 56.0;  Predicted: 40.65
# Actual: 77.0;  Predicted: 50.8
# Actual: 86.0;  Predicted: 56.35
# Actual: 76.0;  Predicted: 44.04
#
#
# Epoch 772
#   Train Error: 20.59600369300763
#   Valid Error: 16.48807199718883
#   Train Loss: 641.7946317078637
# Actual: 76.0;  Predicted: 47.85
# Actual: 63.0;  Predicted: 48.25
# Actual: 75.0;  Predicted: 46.38
# Actual: 29.0;  Predicted: 41.89
# Actual: 75.0;  Predicted: 44.64
# Actual: 63.0;  Predicted: 46.67
# Actual: 56.0;  Predicted: 37.88
# Actual: 77.0;  Predicted: 46.61
# Actual: 86.0;  Predicted: 50.32
# Actual: 76.0;  Predicted: 38.18
#
#
# Epoch 773
#   Train Error: 20.6494180001241
#   Valid Error: 19.60886434906895
#   Train Loss: 645.061375852491
# Actual: 76.0;  Predicted: 48.32
# Actual: 63.0;  Predicted: 48.7
# Actual: 75.0;  Predicted: 47.27
# Actual: 29.0;  Predicted: 42.28
# Actual: 75.0;  Predicted: 45.21
# Actual: 63.0;  Predicted: 47.66
# Actual: 56.0;  Predicted: 37.63
# Actual: 77.0;  Predicted: 47.67
# Actual: 86.0;  Predicted: 51.02
# Actual: 76.0;  Predicted: 38.53
#
#
# Epoch 774
#   Train Error: 20.664778267271554
#   Valid Error: 22.714324506741125
#   Train Loss: 646.2673860143443
# Actual: 76.0;  Predicted: 54.58
# Actual: 63.0;  Predicted: 52.19
# Actual: 75.0;  Predicted: 49.94
# Actual: 29.0;  Predicted: 46.52
# Actual: 75.0;  Predicted: 49.13
# Actual: 63.0;  Predicted: 49.94
# Actual: 56.0;  Predicted: 44.9
# Actual: 77.0;  Predicted: 51.06
# Actual: 86.0;  Predicted: 55.47
# Actual: 76.0;  Predicted: 44.36
#
#
# Epoch 775
#   Train Error: 20.643465172971855
#   Valid Error: 24.041727010486195
#   Train Loss: 648.604615758677
# Actual: 76.0;  Predicted: 58.0
# Actual: 63.0;  Predicted: 55.53
# Actual: 75.0;  Predicted: 54.04
# Actual: 29.0;  Predicted: 48.86
# Actual: 75.0;  Predicted: 52.79
# Actual: 63.0;  Predicted: 52.14
# Actual: 56.0;  Predicted: 42.3
# Actual: 77.0;  Predicted: 55.08
# Actual: 86.0;  Predicted: 60.12
# Actual: 76.0;  Predicted: 45.62
#
#
# Epoch 776
#   Train Error: 20.598054564668335
#   Valid Error: 17.360857880231247
#   Train Loss: 639.7212859607133
# Actual: 76.0;  Predicted: 49.99
# Actual: 63.0;  Predicted: 50.2
# Actual: 75.0;  Predicted: 48.86
# Actual: 29.0;  Predicted: 43.61
# Actual: 75.0;  Predicted: 47.01
# Actual: 63.0;  Predicted: 49.16
# Actual: 56.0;  Predicted: 39.81
# Actual: 77.0;  Predicted: 48.87
# Actual: 86.0;  Predicted: 53.54
# Actual: 76.0;  Predicted: 39.76
#
#
# Epoch 777
#   Train Error: 20.592408535138485
#   Valid Error: 19.235193641440382
#   Train Loss: 646.6359027800013
# Actual: 76.0;  Predicted: 50.87
# Actual: 63.0;  Predicted: 51.19
# Actual: 75.0;  Predicted: 48.91
# Actual: 29.0;  Predicted: 44.51
# Actual: 75.0;  Predicted: 47.41
# Actual: 63.0;  Predicted: 49.81
# Actual: 56.0;  Predicted: 38.71
# Actual: 77.0;  Predicted: 49.23
# Actual: 86.0;  Predicted: 53.79
# Actual: 76.0;  Predicted: 40.64
#
#
# Epoch 778
#   Train Error: 20.66461260155184
#   Valid Error: 23.26902415451494
#   Train Loss: 649.2977870253266
# Actual: 76.0;  Predicted: 55.76
# Actual: 63.0;  Predicted: 55.73
# Actual: 75.0;  Predicted: 52.99
# Actual: 29.0;  Predicted: 48.74
# Actual: 75.0;  Predicted: 51.75
# Actual: 63.0;  Predicted: 53.01
# Actual: 56.0;  Predicted: 52.48
# Actual: 77.0;  Predicted: 53.5
# Actual: 86.0;  Predicted: 58.95
# Actual: 76.0;  Predicted: 45.31
#
#
# Epoch 779
#   Train Error: 20.732367469962075
#   Valid Error: 19.33401026309115
#   Train Loss: 640.396882354236
# Actual: 76.0;  Predicted: 54.3
# Actual: 63.0;  Predicted: 54.3
# Actual: 75.0;  Predicted: 51.41
# Actual: 29.0;  Predicted: 47.29
# Actual: 75.0;  Predicted: 50.58
# Actual: 63.0;  Predicted: 51.94
# Actual: 56.0;  Predicted: 51.22
# Actual: 77.0;  Predicted: 52.15
# Actual: 86.0;  Predicted: 57.21
# Actual: 76.0;  Predicted: 43.96
#
#
# Epoch 780
#   Train Error: 20.57170599463576
#   Valid Error: 18.60623561525808
#   Train Loss: 648.1486976498463
# Actual: 76.0;  Predicted: 50.26
# Actual: 63.0;  Predicted: 50.48
# Actual: 75.0;  Predicted: 48.44
# Actual: 29.0;  Predicted: 43.94
# Actual: 75.0;  Predicted: 47.06
# Actual: 63.0;  Predicted: 48.95
# Actual: 56.0;  Predicted: 48.04
# Actual: 77.0;  Predicted: 47.78
# Actual: 86.0;  Predicted: 53.16
# Actual: 76.0;  Predicted: 40.39
#
#
# Epoch 781
#   Train Error: 20.607270702750668
#   Valid Error: 21.318334486878033
#   Train Loss: 642.4669944888255
# Actual: 76.0;  Predicted: 53.75
# Actual: 63.0;  Predicted: 53.74
# Actual: 75.0;  Predicted: 51.46
# Actual: 29.0;  Predicted: 47.0
# Actual: 75.0;  Predicted: 50.27
# Actual: 63.0;  Predicted: 50.97
# Actual: 56.0;  Predicted: 50.97
# Actual: 77.0;  Predicted: 52.02
# Actual: 86.0;  Predicted: 56.9
# Actual: 76.0;  Predicted: 43.36
#
#
# Epoch 782
#   Train Error: 20.62295793148683
#   Valid Error: 19.27238601388283
#   Train Loss: 649.2368929503394
# Actual: 76.0;  Predicted: 49.8
# Actual: 63.0;  Predicted: 50.29
# Actual: 75.0;  Predicted: 48.84
# Actual: 29.0;  Predicted: 44.14
# Actual: 75.0;  Predicted: 46.52
# Actual: 63.0;  Predicted: 49.24
# Actual: 56.0;  Predicted: 47.36
# Actual: 77.0;  Predicted: 49.37
# Actual: 86.0;  Predicted: 52.45
# Actual: 76.0;  Predicted: 39.92
#
#
# Epoch 783
#   Train Error: 20.611028508683997
#   Valid Error: 19.85628935434286
#   Train Loss: 645.9885574090677
# Actual: 76.0;  Predicted: 52.2
# Actual: 63.0;  Predicted: 52.33
# Actual: 75.0;  Predicted: 49.2
# Actual: 29.0;  Predicted: 45.91
# Actual: 75.0;  Predicted: 48.73
# Actual: 63.0;  Predicted: 49.54
# Actual: 56.0;  Predicted: 43.49
# Actual: 77.0;  Predicted: 50.03
# Actual: 86.0;  Predicted: 54.73
# Actual: 76.0;  Predicted: 42.04
#
#
# Epoch 784
#   Train Error: 20.655943634604217
#   Valid Error: 18.153904701899556
#   Train Loss: 641.7922413310066
# Actual: 76.0;  Predicted: 51.61
# Actual: 63.0;  Predicted: 51.63
# Actual: 75.0;  Predicted: 47.83
# Actual: 29.0;  Predicted: 44.99
# Actual: 75.0;  Predicted: 48.11
# Actual: 63.0;  Predicted: 49.72
# Actual: 56.0;  Predicted: 37.53
# Actual: 77.0;  Predicted: 49.18
# Actual: 86.0;  Predicted: 54.27
# Actual: 76.0;  Predicted: 41.32
#
#
# Epoch 785
#   Train Error: 20.684813810733154
#   Valid Error: 18.5174665728819
#   Train Loss: 642.9054490386462
# Actual: 76.0;  Predicted: 54.65
# Actual: 63.0;  Predicted: 54.14
# Actual: 75.0;  Predicted: 52.37
# Actual: 29.0;  Predicted: 47.15
# Actual: 75.0;  Predicted: 51.1
# Actual: 63.0;  Predicted: 51.35
# Actual: 56.0;  Predicted: 40.83
# Actual: 77.0;  Predicted: 52.82
# Actual: 86.0;  Predicted: 58.07
# Actual: 76.0;  Predicted: 43.74
#
#
# Epoch 786
#   Train Error: 20.485590254690443
#   Valid Error: 20.707240910206025
#   Train Loss: 637.2361890448899
# Actual: 76.0;  Predicted: 53.87
# Actual: 63.0;  Predicted: 53.99
# Actual: 75.0;  Predicted: 50.88
# Actual: 29.0;  Predicted: 47.0
# Actual: 75.0;  Predicted: 50.09
# Actual: 63.0;  Predicted: 51.34
# Actual: 56.0;  Predicted: 41.81
# Actual: 77.0;  Predicted: 51.87
# Actual: 86.0;  Predicted: 56.41
# Actual: 76.0;  Predicted: 43.43
#
#
# Epoch 787
#   Train Error: 20.598201953943455
#   Valid Error: 18.01002917243439
#   Train Loss: 645.1912686707543
# Actual: 76.0;  Predicted: 51.21
# Actual: 63.0;  Predicted: 51.21
# Actual: 75.0;  Predicted: 48.97
# Actual: 29.0;  Predicted: 44.62
# Actual: 75.0;  Predicted: 47.68
# Actual: 63.0;  Predicted: 49.51
# Actual: 56.0;  Predicted: 41.36
# Actual: 77.0;  Predicted: 49.61
# Actual: 86.0;  Predicted: 53.75
# Actual: 76.0;  Predicted: 41.06
#
#
# Epoch 788
#   Train Error: 20.681370661808895
#   Valid Error: 19.22231296428199
#   Train Loss: 641.6324993196081
# Actual: 76.0;  Predicted: 53.82
# Actual: 63.0;  Predicted: 53.5
# Actual: 75.0;  Predicted: 50.86
# Actual: 29.0;  Predicted: 46.62
# Actual: 75.0;  Predicted: 50.38
# Actual: 63.0;  Predicted: 51.5
# Actual: 56.0;  Predicted: 40.88
# Actual: 77.0;  Predicted: 51.3
# Actual: 86.0;  Predicted: 56.84
# Actual: 76.0;  Predicted: 43.19
#
#
# Epoch 789
#   Train Error: 20.451737865836606
#   Valid Error: 19.14237735340896
#   Train Loss: 644.0739781113922
# Actual: 76.0;  Predicted: 50.6
# Actual: 63.0;  Predicted: 50.62
# Actual: 75.0;  Predicted: 48.59
# Actual: 29.0;  Predicted: 44.1
# Actual: 75.0;  Predicted: 47.34
# Actual: 63.0;  Predicted: 49.96
# Actual: 56.0;  Predicted: 38.78
# Actual: 77.0;  Predicted: 50.06
# Actual: 86.0;  Predicted: 53.32
# Actual: 76.0;  Predicted: 40.48
#
#
# Epoch 790
#   Train Error: 20.6282712060052
#   Valid Error: 18.390639555107043
#   Train Loss: 642.4220060754994
# Actual: 76.0;  Predicted: 52.93
# Actual: 63.0;  Predicted: 52.83
# Actual: 75.0;  Predicted: 47.83
# Actual: 29.0;  Predicted: 46.04
# Actual: 75.0;  Predicted: 49.51
# Actual: 63.0;  Predicted: 50.58
# Actual: 56.0;  Predicted: 37.79
# Actual: 77.0;  Predicted: 51.12
# Actual: 86.0;  Predicted: 55.86
# Actual: 76.0;  Predicted: 42.58
#
#
# Epoch 791
#   Train Error: 20.524712766778197
#   Valid Error: 21.113420393860455
#   Train Loss: 644.2288878393955
# Actual: 76.0;  Predicted: 51.85
# Actual: 63.0;  Predicted: 51.84
# Actual: 75.0;  Predicted: 48.03
# Actual: 29.0;  Predicted: 45.14
# Actual: 75.0;  Predicted: 48.31
# Actual: 63.0;  Predicted: 50.32
# Actual: 56.0;  Predicted: 38.26
# Actual: 77.0;  Predicted: 50.86
# Actual: 86.0;  Predicted: 54.42
# Actual: 76.0;  Predicted: 41.64
#
#
# Epoch 792
#   Train Error: 20.626539214485152
#   Valid Error: 21.307100573789725
#   Train Loss: 652.8122383492891
# Actual: 76.0;  Predicted: 54.56
# Actual: 63.0;  Predicted: 54.54
# Actual: 75.0;  Predicted: 51.71
# Actual: 29.0;  Predicted: 47.46
# Actual: 75.0;  Predicted: 50.74
# Actual: 63.0;  Predicted: 52.21
# Actual: 56.0;  Predicted: 42.74
# Actual: 77.0;  Predicted: 53.33
# Actual: 86.0;  Predicted: 57.19
# Actual: 76.0;  Predicted: 44.05
#
#
# Epoch 793
#   Train Error: 20.684348322497584
#   Valid Error: 21.308122357118478
#   Train Loss: 641.1593928102587
# Actual: 76.0;  Predicted: 54.32
# Actual: 63.0;  Predicted: 54.21
# Actual: 75.0;  Predicted: 51.09
# Actual: 29.0;  Predicted: 47.24
# Actual: 75.0;  Predicted: 50.47
# Actual: 63.0;  Predicted: 51.55
# Actual: 56.0;  Predicted: 41.36
# Actual: 77.0;  Predicted: 51.04
# Actual: 86.0;  Predicted: 56.63
# Actual: 76.0;  Predicted: 43.76
#
#
# Epoch 794
#   Train Error: 20.578502377452573
#   Valid Error: 21.416391909701154
#   Train Loss: 640.6163930423925
# Actual: 76.0;  Predicted: 52.5
# Actual: 63.0;  Predicted: 52.5
# Actual: 75.0;  Predicted: 50.15
# Actual: 29.0;  Predicted: 45.97
# Actual: 75.0;  Predicted: 49.08
# Actual: 63.0;  Predicted: 50.73
# Actual: 56.0;  Predicted: 41.61
# Actual: 77.0;  Predicted: 50.76
# Actual: 86.0;  Predicted: 55.33
# Actual: 76.0;  Predicted: 42.2
#
#
# Epoch 795
#   Train Error: 20.564110972033717
#   Valid Error: 20.63554774904714
#   Train Loss: 641.3150444656122
# Actual: 76.0;  Predicted: 53.57
# Actual: 63.0;  Predicted: 53.55
# Actual: 75.0;  Predicted: 51.08
# Actual: 29.0;  Predicted: 46.94
# Actual: 75.0;  Predicted: 50.09
# Actual: 63.0;  Predicted: 51.74
# Actual: 56.0;  Predicted: 44.02
# Actual: 77.0;  Predicted: 51.32
# Actual: 86.0;  Predicted: 56.61
# Actual: 76.0;  Predicted: 43.14
#
#
# Epoch 796
#   Train Error: 20.572721175988846
#   Valid Error: 18.31868614270849
#   Train Loss: 653.2066140096696
# Actual: 76.0;  Predicted: 51.49
# Actual: 63.0;  Predicted: 51.53
# Actual: 75.0;  Predicted: 48.5
# Actual: 29.0;  Predicted: 44.9
# Actual: 75.0;  Predicted: 48.17
# Actual: 63.0;  Predicted: 50.1
# Actual: 56.0;  Predicted: 38.23
# Actual: 77.0;  Predicted: 49.28
# Actual: 86.0;  Predicted: 54.27
# Actual: 76.0;  Predicted: 41.25
#
#
# Epoch 797
#   Train Error: 20.57915713732555
#   Valid Error: 21.070184578015965
#   Train Loss: 638.3485797819544
# Actual: 76.0;  Predicted: 52.76
# Actual: 63.0;  Predicted: 52.46
# Actual: 75.0;  Predicted: 48.45
# Actual: 29.0;  Predicted: 45.71
# Actual: 75.0;  Predicted: 49.4
# Actual: 63.0;  Predicted: 50.23
# Actual: 56.0;  Predicted: 37.07
# Actual: 77.0;  Predicted: 50.98
# Actual: 86.0;  Predicted: 55.77
# Actual: 76.0;  Predicted: 42.22
#
#
# Epoch 798
#   Train Error: 20.488415589203704
#   Valid Error: 18.74662340034559
#   Train Loss: 649.1633355812949
# Actual: 76.0;  Predicted: 53.33
# Actual: 63.0;  Predicted: 53.48
# Actual: 75.0;  Predicted: 51.28
# Actual: 29.0;  Predicted: 46.77
# Actual: 75.0;  Predicted: 49.79
# Actual: 63.0;  Predicted: 51.75
# Actual: 56.0;  Predicted: 41.37
# Actual: 77.0;  Predicted: 52.47
# Actual: 86.0;  Predicted: 56.45
# Actual: 76.0;  Predicted: 42.82
#
#
# Epoch 799
#   Train Error: 20.582569506956485
#   Valid Error: 19.84342849138871
#   Train Loss: 642.6734263936028
# Actual: 76.0;  Predicted: 51.11
# Actual: 63.0;  Predicted: 51.09
# Actual: 75.0;  Predicted: 46.96
# Actual: 29.0;  Predicted: 44.41
# Actual: 75.0;  Predicted: 47.89
# Actual: 63.0;  Predicted: 48.52
# Actual: 56.0;  Predicted: 35.84
# Actual: 77.0;  Predicted: 49.27
# Actual: 86.0;  Predicted: 54.3
# Actual: 76.0;  Predicted: 41.06
#
#
# Epoch 800
#   Train Error: 20.610305496659944
# ...
#
#
# Epoch 964
#   Train Error: 20.409776917614213
#   Valid Error: 17.984506625573612
#   Train Loss: 636.8668733190318
# Actual: 76.0;  Predicted: 54.49
# Actual: 63.0;  Predicted: 52.25
# Actual: 75.0;  Predicted: 51.71
# Actual: 29.0;  Predicted: 47.54
# Actual: 75.0;  Predicted: 50.44
# Actual: 63.0;  Predicted: 52.6
# Actual: 56.0;  Predicted: 42.38
# Actual: 77.0;  Predicted: 50.04
# Actual: 86.0;  Predicted: 57.01
# Actual: 76.0;  Predicted: 43.86
#
#
# Epoch 965
#   Train Error: 20.39828897266031
#   Valid Error: 21.143390137015036
#   Train Loss: 626.4320897587011
# Actual: 76.0;  Predicted: 56.79
# Actual: 63.0;  Predicted: 54.79
# Actual: 75.0;  Predicted: 56.57
# Actual: 29.0;  Predicted: 48.6
# Actual: 75.0;  Predicted: 53.36
# Actual: 63.0;  Predicted: 57.27
# Actual: 56.0;  Predicted: 44.18
# Actual: 77.0;  Predicted: 51.74
# Actual: 86.0;  Predicted: 61.44
# Actual: 76.0;  Predicted: 45.32
#
#
# Epoch 966
#   Train Error: 20.230618938834652
#   Valid Error: 19.110745772574713
#   Train Loss: 638.3310676949923
# Actual: 76.0;  Predicted: 50.28
# Actual: 63.0;  Predicted: 49.92
# Actual: 75.0;  Predicted: 50.31
# Actual: 29.0;  Predicted: 44.92
# Actual: 75.0;  Predicted: 47.68
# Actual: 63.0;  Predicted: 50.34
# Actual: 56.0;  Predicted: 38.56
# Actual: 77.0;  Predicted: 46.87
# Actual: 86.0;  Predicted: 53.87
# Actual: 76.0;  Predicted: 40.09
#
#
# Epoch 967
#   Train Error: 20.30909314621511
#   Valid Error: 18.334966492884366
#   Train Loss: 633.9227034772028
# Actual: 76.0;  Predicted: 51.58
# Actual: 63.0;  Predicted: 50.73
# Actual: 75.0;  Predicted: 50.85
# Actual: 29.0;  Predicted: 45.0
# Actual: 75.0;  Predicted: 48.24
# Actual: 63.0;  Predicted: 49.57
# Actual: 56.0;  Predicted: 35.77
# Actual: 77.0;  Predicted: 48.09
# Actual: 86.0;  Predicted: 55.2
# Actual: 76.0;  Predicted: 41.04
#
#
# Epoch 968
#   Train Error: 20.344121865571907
#   Valid Error: 18.72729569962881
#   Train Loss: 632.5870821593238
# Actual: 76.0;  Predicted: 51.98
# Actual: 63.0;  Predicted: 51.05
# Actual: 75.0;  Predicted: 49.45
# Actual: 29.0;  Predicted: 45.38
# Actual: 75.0;  Predicted: 48.69
# Actual: 63.0;  Predicted: 50.27
# Actual: 56.0;  Predicted: 34.97
# Actual: 77.0;  Predicted: 48.12
# Actual: 86.0;  Predicted: 54.63
# Actual: 76.0;  Predicted: 41.34
#
#
# Epoch 969
#   Train Error: 20.38136107113654
#   Valid Error: 20.888403290683783
#   Train Loss: 633.7923649021836
# Actual: 76.0;  Predicted: 54.54
# Actual: 63.0;  Predicted: 53.23
# Actual: 75.0;  Predicted: 53.06
# Actual: 29.0;  Predicted: 47.01
# Actual: 75.0;  Predicted: 51.3
# Actual: 63.0;  Predicted: 53.23
# Actual: 56.0;  Predicted: 40.92
# Actual: 77.0;  Predicted: 51.83
# Actual: 86.0;  Predicted: 57.69
# Actual: 76.0;  Predicted: 43.81
#
#
# Epoch 970
#   Train Error: 20.170442668415156
#   Valid Error: 18.318836878804326
#   Train Loss: 629.6523727667136
# Actual: 76.0;  Predicted: 50.36
# Actual: 63.0;  Predicted: 51.28
# Actual: 75.0;  Predicted: 50.01
# Actual: 29.0;  Predicted: 43.09
# Actual: 75.0;  Predicted: 45.33
# Actual: 63.0;  Predicted: 50.95
# Actual: 56.0;  Predicted: 36.46
# Actual: 77.0;  Predicted: 49.53
# Actual: 86.0;  Predicted: 53.27
# Actual: 76.0;  Predicted: 37.98
#
#
# Epoch 971
#   Train Error: 20.37263998717627
#   Valid Error: 20.432428489610988
#   Train Loss: 627.1012388135566
# Actual: 76.0;  Predicted: 53.17
# Actual: 63.0;  Predicted: 52.67
# Actual: 75.0;  Predicted: 50.51
# Actual: 29.0;  Predicted: 48.04
# Actual: 75.0;  Predicted: 49.84
# Actual: 63.0;  Predicted: 53.99
# Actual: 56.0;  Predicted: 39.68
# Actual: 77.0;  Predicted: 50.0
# Actual: 86.0;  Predicted: 57.41
# Actual: 76.0;  Predicted: 42.43
#
#
# Epoch 972
#   Train Error: 20.293888575817594
#   Valid Error: 19.2708503204642
#   Train Loss: 641.0219811611488
# Actual: 76.0;  Predicted: 54.7
# Actual: 63.0;  Predicted: 53.82
# Actual: 75.0;  Predicted: 53.45
# Actual: 29.0;  Predicted: 48.31
# Actual: 75.0;  Predicted: 51.45
# Actual: 63.0;  Predicted: 55.68
# Actual: 56.0;  Predicted: 41.75
# Actual: 77.0;  Predicted: 50.83
# Actual: 86.0;  Predicted: 58.2
# Actual: 76.0;  Predicted: 43.73
#
#
# Epoch 973
#   Train Error: 20.288997622388813
#   Valid Error: 18.178781750132735
#   Train Loss: 626.4201109839267
# Actual: 76.0;  Predicted: 53.07
# Actual: 63.0;  Predicted: 51.86
# Actual: 75.0;  Predicted: 51.54
# Actual: 29.0;  Predicted: 45.34
# Actual: 75.0;  Predicted: 49.48
# Actual: 63.0;  Predicted: 52.8
# Actual: 56.0;  Predicted: 37.32
# Actual: 77.0;  Predicted: 48.79
# Actual: 86.0;  Predicted: 55.7
# Actual: 76.0;  Predicted: 42.47
#
#
# Epoch 974
#   Train Error: 20.165988751607724
#   Valid Error: 20.562614033523115
#   Train Loss: 628.0200530505571
# Actual: 76.0;  Predicted: 51.94
# Actual: 63.0;  Predicted: 50.02
# Actual: 75.0;  Predicted: 46.96
# Actual: 29.0;  Predicted: 44.92
# Actual: 75.0;  Predicted: 48.64
# Actual: 63.0;  Predicted: 51.19
# Actual: 56.0;  Predicted: 36.57
# Actual: 77.0;  Predicted: 47.46
# Actual: 86.0;  Predicted: 54.6
# Actual: 76.0;  Predicted: 41.14
#
#
# Epoch 975
#   Train Error: 20.381604462304384
#   Valid Error: 18.339025664098056
#   Train Loss: 630.911144819416
# Actual: 76.0;  Predicted: 56.35
# Actual: 63.0;  Predicted: 53.07
# Actual: 75.0;  Predicted: 53.47
# Actual: 29.0;  Predicted: 48.58
# Actual: 75.0;  Predicted: 52.44
# Actual: 63.0;  Predicted: 52.96
# Actual: 56.0;  Predicted: 37.04
# Actual: 77.0;  Predicted: 51.0
# Actual: 86.0;  Predicted: 60.12
# Actual: 76.0;  Predicted: 44.77
#
#
# Epoch 976
#   Train Error: 20.281645047193752
#   Valid Error: 19.58158141200982
#   Train Loss: 628.5411677126025
# Actual: 76.0;  Predicted: 52.92
# Actual: 63.0;  Predicted: 51.85
# Actual: 75.0;  Predicted: 52.08
# Actual: 29.0;  Predicted: 45.58
# Actual: 75.0;  Predicted: 49.76
# Actual: 63.0;  Predicted: 52.44
# Actual: 56.0;  Predicted: 40.12
# Actual: 77.0;  Predicted: 50.65
# Actual: 86.0;  Predicted: 55.82
# Actual: 76.0;  Predicted: 41.95
#
#
# Epoch 977
#   Train Error: 20.303499705578336
#   Valid Error: 18.825239348180087
#   Train Loss: 628.6918374983991
# Actual: 76.0;  Predicted: 53.16
# Actual: 63.0;  Predicted: 52.18
# Actual: 75.0;  Predicted: 49.62
# Actual: 29.0;  Predicted: 46.91
# Actual: 75.0;  Predicted: 49.7
# Actual: 63.0;  Predicted: 52.31
# Actual: 56.0;  Predicted: 34.42
# Actual: 77.0;  Predicted: 48.08
# Actual: 86.0;  Predicted: 55.48
# Actual: 76.0;  Predicted: 42.12
#
#
# Epoch 978
#   Train Error: 20.324883344019774
#   Valid Error: 19.60534301313382
#   Train Loss: 627.307885341957
# Actual: 76.0;  Predicted: 53.15
# Actual: 63.0;  Predicted: 52.28
# Actual: 75.0;  Predicted: 52.34
# Actual: 29.0;  Predicted: 46.8
# Actual: 75.0;  Predicted: 49.72
# Actual: 63.0;  Predicted: 53.3
# Actual: 56.0;  Predicted: 42.41
# Actual: 77.0;  Predicted: 48.91
# Actual: 86.0;  Predicted: 55.69
# Actual: 76.0;  Predicted: 42.24
#
#
# Epoch 979
#   Train Error: 20.334777086539475
#   Valid Error: 18.983642726268585
#   Train Loss: 633.762538722304
# Actual: 76.0;  Predicted: 55.05
# Actual: 63.0;  Predicted: 53.63
# Actual: 75.0;  Predicted: 53.57
# Actual: 29.0;  Predicted: 49.46
# Actual: 75.0;  Predicted: 51.4
# Actual: 63.0;  Predicted: 53.82
# Actual: 56.0;  Predicted: 41.69
# Actual: 77.0;  Predicted: 50.86
# Actual: 86.0;  Predicted: 58.16
# Actual: 76.0;  Predicted: 43.91
#
#
# Epoch 980
#   Train Error: 20.330473866135563
#   Valid Error: 20.66509806068198
#   Train Loss: 638.5974356229189
# Actual: 76.0;  Predicted: 52.49
# Actual: 63.0;  Predicted: 52.96
# Actual: 75.0;  Predicted: 51.25
# Actual: 29.0;  Predicted: 47.06
# Actual: 75.0;  Predicted: 48.84
# Actual: 63.0;  Predicted: 51.27
# Actual: 56.0;  Predicted: 40.12
# Actual: 77.0;  Predicted: 49.2
# Actual: 86.0;  Predicted: 54.47
# Actual: 76.0;  Predicted: 41.88
#
#
# Epoch 981
#   Train Error: 20.404362280006964
#   Valid Error: 22.548028668153634
#   Train Loss: 634.3143230500768
# Actual: 76.0;  Predicted: 52.32
# Actual: 63.0;  Predicted: 52.5
# Actual: 75.0;  Predicted: 52.39
# Actual: 29.0;  Predicted: 47.48
# Actual: 75.0;  Predicted: 48.88
# Actual: 63.0;  Predicted: 52.85
# Actual: 56.0;  Predicted: 40.53
# Actual: 77.0;  Predicted: 48.11
# Actual: 86.0;  Predicted: 55.49
# Actual: 76.0;  Predicted: 41.7
#
#
# Epoch 982
#   Train Error: 20.333161296566907
#   Valid Error: 19.434099734408186
#   Train Loss: 627.1326366487096
# Actual: 76.0;  Predicted: 52.89
# Actual: 63.0;  Predicted: 51.18
# Actual: 75.0;  Predicted: 50.21
# Actual: 29.0;  Predicted: 46.26
# Actual: 75.0;  Predicted: 49.1
# Actual: 63.0;  Predicted: 51.47
# Actual: 56.0;  Predicted: 38.78
# Actual: 77.0;  Predicted: 48.4
# Actual: 86.0;  Predicted: 55.51
# Actual: 76.0;  Predicted: 42.24
#
#
# Epoch 983
#   Train Error: 20.35364440473846
#   Valid Error: 17.440091364592025
#   Train Loss: 637.175597143955
# Actual: 76.0;  Predicted: 54.35
# Actual: 63.0;  Predicted: 52.02
# Actual: 75.0;  Predicted: 49.49
# Actual: 29.0;  Predicted: 47.69
# Actual: 75.0;  Predicted: 50.32
# Actual: 63.0;  Predicted: 52.08
# Actual: 56.0;  Predicted: 36.6
# Actual: 77.0;  Predicted: 49.93
# Actual: 86.0;  Predicted: 57.05
# Actual: 76.0;  Predicted: 43.07
#
#
# Epoch 984
#   Train Error: 20.340539174863057
#   Valid Error: 18.358841683100728
#   Train Loss: 628.0528349329213
# Actual: 76.0;  Predicted: 55.15
# Actual: 63.0;  Predicted: 53.49
# Actual: 75.0;  Predicted: 52.39
# Actual: 29.0;  Predicted: 48.16
# Actual: 75.0;  Predicted: 52.16
# Actual: 63.0;  Predicted: 54.3
# Actual: 56.0;  Predicted: 36.93
# Actual: 77.0;  Predicted: 50.63
# Actual: 86.0;  Predicted: 58.5
# Actual: 76.0;  Predicted: 43.43
#
#
# Epoch 985
#   Train Error: 20.30624341667318
#   Valid Error: 18.400878535891042
#   Train Loss: 626.8828069968301
# Actual: 76.0;  Predicted: 53.05
# Actual: 63.0;  Predicted: 52.9
# Actual: 75.0;  Predicted: 53.34
# Actual: 29.0;  Predicted: 47.2
# Actual: 75.0;  Predicted: 50.12
# Actual: 63.0;  Predicted: 54.38
# Actual: 56.0;  Predicted: 42.04
# Actual: 77.0;  Predicted: 52.24
# Actual: 86.0;  Predicted: 56.33
# Actual: 76.0;  Predicted: 41.52
#
#
# Epoch 986
#   Train Error: 20.214906629058774
#   Valid Error: 19.53863236510638
#   Train Loss: 623.3279083752242
# Actual: 76.0;  Predicted: 54.73
# Actual: 63.0;  Predicted: 52.05
# Actual: 75.0;  Predicted: 51.1
# Actual: 29.0;  Predicted: 47.19
# Actual: 75.0;  Predicted: 50.24
# Actual: 63.0;  Predicted: 51.59
# Actual: 56.0;  Predicted: 37.23
# Actual: 77.0;  Predicted: 49.04
# Actual: 86.0;  Predicted: 57.19
# Actual: 76.0;  Predicted: 43.36
#
#
# Epoch 987
#   Train Error: 20.34412535907325
#   Valid Error: 18.012658572891382
#   Train Loss: 627.9632730953028
# Actual: 76.0;  Predicted: 52.76
# Actual: 63.0;  Predicted: 51.66
# Actual: 75.0;  Predicted: 52.71
# Actual: 29.0;  Predicted: 45.95
# Actual: 75.0;  Predicted: 49.72
# Actual: 63.0;  Predicted: 53.29
# Actual: 56.0;  Predicted: 39.09
# Actual: 77.0;  Predicted: 49.52
# Actual: 86.0;  Predicted: 56.63
# Actual: 76.0;  Predicted: 41.53
#
#
# Epoch 988
#   Train Error: 20.3171178298284
#   Valid Error: 19.42513586248009
#   Train Loss: 632.1715658219134
# Actual: 76.0;  Predicted: 52.67
# Actual: 63.0;  Predicted: 51.74
# Actual: 75.0;  Predicted: 50.92
# Actual: 29.0;  Predicted: 45.76
# Actual: 75.0;  Predicted: 49.19
# Actual: 63.0;  Predicted: 51.49
# Actual: 56.0;  Predicted: 41.14
# Actual: 77.0;  Predicted: 50.8
# Actual: 86.0;  Predicted: 54.69
# Actual: 76.0;  Predicted: 41.77
#
#
# Epoch 989
#   Train Error: 20.29021382084012
#   Valid Error: 25.067165930294298
#   Train Loss: 630.6728535636527
# Actual: 76.0;  Predicted: 51.35
# Actual: 63.0;  Predicted: 50.67
# Actual: 75.0;  Predicted: 51.82
# Actual: 29.0;  Predicted: 44.99
# Actual: 75.0;  Predicted: 48.12
# Actual: 63.0;  Predicted: 52.76
# Actual: 56.0;  Predicted: 43.07
# Actual: 77.0;  Predicted: 48.88
# Actual: 86.0;  Predicted: 54.0
# Actual: 76.0;  Predicted: 40.43
#
#
# Epoch 990
#   Train Error: 20.382321318073235
#   Valid Error: 22.987514421777817
#   Train Loss: 630.6953935466829
# Actual: 76.0;  Predicted: 54.55
# Actual: 63.0;  Predicted: 52.89
# Actual: 75.0;  Predicted: 52.31
# Actual: 29.0;  Predicted: 48.64
# Actual: 75.0;  Predicted: 50.43
# Actual: 63.0;  Predicted: 53.29
# Actual: 56.0;  Predicted: 42.11
# Actual: 77.0;  Predicted: 51.44
# Actual: 86.0;  Predicted: 57.19
# Actual: 76.0;  Predicted: 43.16
#
#
# Epoch 991
#   Train Error: 20.328703354896973
#   Valid Error: 20.965956493488793
#   Train Loss: 634.3478253474001
# Actual: 76.0;  Predicted: 53.28
# Actual: 63.0;  Predicted: 54.77
# Actual: 75.0;  Predicted: 50.83
# Actual: 29.0;  Predicted: 49.51
# Actual: 75.0;  Predicted: 49.84
# Actual: 63.0;  Predicted: 51.64
# Actual: 56.0;  Predicted: 42.92
# Actual: 77.0;  Predicted: 50.81
# Actual: 86.0;  Predicted: 56.11
# Actual: 76.0;  Predicted: 42.31
#
#
# Epoch 992
#   Train Error: 20.239119246199323
#   Valid Error: 19.528936404626347
#   Train Loss: 633.7795260069801
# Actual: 76.0;  Predicted: 50.64
# Actual: 63.0;  Predicted: 49.57
# Actual: 75.0;  Predicted: 47.47
# Actual: 29.0;  Predicted: 44.99
# Actual: 75.0;  Predicted: 47.68
# Actual: 63.0;  Predicted: 49.79
# Actual: 56.0;  Predicted: 32.06
# Actual: 77.0;  Predicted: 48.34
# Actual: 86.0;  Predicted: 53.4
# Actual: 76.0;  Predicted: 39.93
#
#
# Epoch 993
#   Train Error: 20.295199669820107
#   Valid Error: 17.003598815029108
#   Train Loss: 633.1727314933402
# Actual: 76.0;  Predicted: 50.75
# Actual: 63.0;  Predicted: 49.6
# Actual: 75.0;  Predicted: 52.46
# Actual: 29.0;  Predicted: 44.49
# Actual: 75.0;  Predicted: 48.02
# Actual: 63.0;  Predicted: 52.66
# Actual: 56.0;  Predicted: 39.04
# Actual: 77.0;  Predicted: 47.93
# Actual: 86.0;  Predicted: 55.3
# Actual: 76.0;  Predicted: 39.78
#
#
# Epoch 994
#   Train Error: 20.368942030750045
#   Valid Error: 18.396821179436248
#   Train Loss: 634.48644269099
# Actual: 76.0;  Predicted: 51.69
# Actual: 63.0;  Predicted: 50.86
# Actual: 75.0;  Predicted: 51.67
# Actual: 29.0;  Predicted: 43.59
# Actual: 75.0;  Predicted: 46.59
# Actual: 63.0;  Predicted: 52.0
# Actual: 56.0;  Predicted: 38.69
# Actual: 77.0;  Predicted: 47.69
# Actual: 86.0;  Predicted: 53.95
# Actual: 76.0;  Predicted: 39.32
#
#
# Epoch 995
#   Train Error: 20.44057014330509
#   Valid Error: 21.14343754296164
#   Train Loss: 626.9330864577997
# Actual: 76.0;  Predicted: 50.27
# Actual: 63.0;  Predicted: 51.98
# Actual: 75.0;  Predicted: 48.75
# Actual: 29.0;  Predicted: 46.65
# Actual: 75.0;  Predicted: 47.03
# Actual: 63.0;  Predicted: 50.09
# Actual: 56.0;  Predicted: 41.4
# Actual: 77.0;  Predicted: 48.33
# Actual: 86.0;  Predicted: 52.35
# Actual: 76.0;  Predicted: 40.02
#
#
# Epoch 996
#   Train Error: 20.43361975893905
#   Valid Error: 15.444269791390132
#   Train Loss: 638.7812855204597
# Actual: 76.0;  Predicted: 53.19
# Actual: 63.0;  Predicted: 51.7
# Actual: 75.0;  Predicted: 53.14
# Actual: 29.0;  Predicted: 46.89
# Actual: 75.0;  Predicted: 49.78
# Actual: 63.0;  Predicted: 53.35
# Actual: 56.0;  Predicted: 42.42
# Actual: 77.0;  Predicted: 48.03
# Actual: 86.0;  Predicted: 56.14
# Actual: 76.0;  Predicted: 41.89
#
#
# Epoch 997
#   Train Error: 20.372021383654303
#   Valid Error: 20.355872663479406
#   Train Loss: 634.8859252929688
# Actual: 76.0;  Predicted: 51.82
# Actual: 63.0;  Predicted: 50.7
# Actual: 75.0;  Predicted: 50.06
# Actual: 29.0;  Predicted: 45.15
# Actual: 75.0;  Predicted: 48.62
# Actual: 63.0;  Predicted: 51.37
# Actual: 56.0;  Predicted: 36.93
# Actual: 77.0;  Predicted: 47.4
# Actual: 86.0;  Predicted: 53.87
# Actual: 76.0;  Predicted: 40.6
#
#
# Epoch 998
#   Train Error: 20.301202579744146
#   Valid Error: 18.347477033300308
#   Train Loss: 636.8761346535605
# Actual: 76.0;  Predicted: 50.94
# Actual: 63.0;  Predicted: 51.04
# Actual: 75.0;  Predicted: 49.25
# Actual: 29.0;  Predicted: 45.92
# Actual: 75.0;  Predicted: 47.84
# Actual: 63.0;  Predicted: 51.04
# Actual: 56.0;  Predicted: 38.7
# Actual: 77.0;  Predicted: 49.63
# Actual: 86.0;  Predicted: 53.34
# Actual: 76.0;  Predicted: 40.15
#
#
# Epoch 999
#   Train Error: 20.3461778961943
#   Valid Error: 18.896338527642406
#   Train Loss: 631.2928256675846
# Actual: 76.0;  Predicted: 50.75
# Actual: 63.0;  Predicted: 50.2
# Actual: 75.0;  Predicted: 49.93
# Actual: 29.0;  Predicted: 45.38
# Actual: 75.0;  Predicted: 47.89
# Actual: 63.0;  Predicted: 52.1
# Actual: 56.0;  Predicted: 39.85
# Actual: 77.0;  Predicted: 49.22
# Actual: 86.0;  Predicted: 53.51
# Actual: 76.0;  Predicted: 40.05
#
#
# Epoch 1000
#   Train Error: 20.27637157321224
#   Valid Error: 18.495676577669904
#   Train Loss: 629.0997049300397
# Actual: 76.0;  Predicted: 51.79
# Actual: 63.0;  Predicted: 51.21
# Actual: 75.0;  Predicted: 49.4
# Actual: 29.0;  Predicted: 46.61
# Actual: 75.0;  Predicted: 48.73
# Actual: 63.0;  Predicted: 51.53
# Actual: 56.0;  Predicted: 37.96
# Actual: 77.0;  Predicted: 48.1
# Actual: 86.0;  Predicted: 54.39
# Actual: 76.0;  Predicted: 41.07
# Final Training Accuracy: 79.72362842678776
# Final Validation Accuracy: 81.50432342233009

# %% [markdown]
# # Baseline Model

# %% [markdown]
# # EXPERIMENTING SECTION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC, LinearSVC
from xgboost import XGBClassifier

from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score 
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
features = ["duration", "key", "mode", "time_signature", "acousticness", "danceability", "energy", "instrumentalness", "liveness", "loudness", "speechiness", "valence", "tempo"]
training = normalized_df.sample(frac = 0.8,random_state = 420)
# add to code before training SGDRegressor model

X_train = training[features]
y_train = training['popularity']
X_test = normalized_df.drop(training.index)[features]

scaler = StandardScaler()
scaler.fit(X_train)
X_t = scaler.transform(X_train)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_t, y_train, test_size = 0.2, random_state = 420)

# %%
SGD_Model = linear_model.SGDRegressor()
SGD_Model.fit(X_train, y_train)
SGD_Predict = SGD_Model.predict(X_valid)
predict = pd.DataFrame(SGD_Predict)
predict = predict.reset_index(drop=True)
val = pd.DataFrame(y_valid)
val = val.reset_index(drop=True)
compare = pd.concat([predict, val], axis=1)
compare
# Out:
#             0  popularity
# 0    0.470431        0.80
# 1    0.478930        0.63
# 2    0.123215        0.30
# 3    0.460689        0.03
# 4    0.478892        0.61
# ..        ...         ...
# 875  0.450532        0.06
# 876  0.464413        0.63
# 877  0.489867        0.02
# 878  0.483063        0.67
# 879  0.165661        0.53
#
# [880 rows x 2 columns]
